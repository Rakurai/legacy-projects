# %% [markdown]
# # Capability Group Analysis
#
# Analyzes the locked capability assignments (from `capability_defs.json`) for the
# ~852 callee functions reachable from command/spell/spec entry points.
#
# **Focus:**
# 1. Load locked group assignments and resolve embeddings
# 2. **Intra-group cohesion** — how tightly clustered is each group?
# 3. **Inter-group similarity** — which groups overlap? Which functions fit better elsewhere?
# 4. **t-SNE visualisation** — per-group and global embedding landscape
#
# Uses `EmbeddingRefiner` from the clustering pipeline for similarity matrices,
# outlier detection, and regroup suggestions.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# ── Setup & imports ──────────────────────────────────────────────────
from __future__ import annotations

import json
import pickle
from collections import Counter, defaultdict
from pathlib import Path

import numpy as np
import networkx as nx
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import matplotlib.cm as cm

HERE = Path(".").resolve()
CLUSTERING_DIR = HERE / "clustering"

import legacy_common.doc_db as ddb
import legacy_common.doxygen_graph as dg
import legacy_common.doxygen_parse as dp
import legacy_common.openai_embeddings as oai_emb
from legacy_common.embedding_refiner import EmbeddingRefiner
from legacy_common.subsystem_utils import Subsystem

# ── Load artifacts ───────────────────────────────────────────────────
graph = dg.load_graph(CLUSTERING_DIR / "code_graph.gml")
entity_db = dp.load_db(CLUSTERING_DIR / "code_graph.json")
doc_db = ddb.DocumentDB()
doc_db.load(ddb.DOC_DB_PATH)

with open(HERE / "capability_defs.json") as f:
    CAPABILITY_DEFS: dict[str, dict] = json.load(f)

# Build quick lookups
GROUP_TYPE = {name: d["type"] for name, d in CAPABILITY_DEFS.items()}
TYPE_ORDER = ["utility", "infrastructure", "policy", "projection", "domain"]
TYPE_COLORS = {
    "utility":        "#7f7f7f",
    "infrastructure": "#8c564b",
    "policy":         "#d62728",
    "projection":     "#ff7f0e",
    "domain":         "#1f77b4",
}

# ── Initialise EmbeddingRefiner (backed by Qwen3-Embedding-8B via LM Studio) ──
refiner = EmbeddingRefiner(entity_db, graph, doc_db)
refiner.load_sbert_model()

print(f"Graph: {graph.number_of_nodes()} nodes, {graph.number_of_edges()} edges")
print(f"Entity DB: {len(entity_db.entities)} entities")
print(f"Doc DB: {doc_db.count()} documents")
type_summary = ", ".join(
    f"{t}={sum(1 for v in CAPABILITY_DEFS.values() if v['type'] == t)}"
    for t in TYPE_ORDER
)
print(f"Capability groups: {len(CAPABILITY_DEFS)} ({type_summary})")
print(f"Embedding endpoint: {oai_emb.BASE_URL}  model: {oai_emb.MODEL}")

# %matplotlib inline
plt.rcParams.update({"figure.dpi": 120, "figure.figsize": (12, 8)})
# Out:
# 2026-03-13 16:42:13.795 | INFO     | clustering.doxygen_graph:load_graph:421 - Graph loaded from /Users/QTE2333/repos/legacy/.ai/gen_docs/clustering/code_graph.gml, nodes: 14507, edges: 44544
# Graph: 14507 nodes, 44544 edges
# Entity DB: 5305 entities
# Doc DB: 5293 documents
# Capability groups: 30 (utility=7, infrastructure=3, policy=4, projection=2, domain=14)
# Embedding endpoint: http://localhost:4000/v1  model: text-embedding-qwen3-embedding-8b

# %% [markdown]
# ## Step 1: Extract transitive call trees
#
# Find all entry-point functions — `do_*` (command handlers), `spell_*` (spell
# effect implementations), and `spec_*` (NPC special functions) — then BFS along
# `calls` edges to collect every reachable function. This captures the true
# dependency footprint, including cross-group dependencies at depth ≥2.
#
# Entry points are excluded from each other's callee sets.
# We track call depth per callee for later analysis.

# %%
# ── Helpers ──────────────────────────────────────────────────────────
ENTRY_PREFIXES = ("do_", "spell_", "spec_")

def entry_point_name(sig: str) -> str:
    """Extract the short name (do_kill, spell_fireball, spec_guard) from a signature."""
    for prefix in ENTRY_PREFIXES:
        idx = sig.find(prefix)
        if idx >= 0:
            end = sig.find("(", idx)
            return sig[idx:end] if end >= 0 else sig[idx:]
    return sig

def bare_name(sig: str) -> str:
    paren = sig.find("(")
    if paren > 0:
        sig = sig[:paren]
    space = sig.rfind(" ")
    if space > 0:
        sig = sig[space + 1:]
    return sig

def is_entry_point(name: str) -> bool:
    """Check if a function name contains an entry-point prefix."""
    return any(f" {p}" in name or name.startswith(p) for p in ENTRY_PREFIXES)

def get_calls_successors(g, node_id):
    """Return set of nodes reachable via a single 'calls' edge from node_id."""
    return {v for _, v, ed in g.edges(node_id, data=True)
            if ed.get("type") == "calls"}

def transitive_callees_bfs(g, start_node, exclude_nodes):
    """BFS along 'calls' edges. Returns dict {node_id: min_depth}."""
    visited = {}
    queue = []
    for callee in get_calls_successors(g, start_node):
        if callee not in exclude_nodes and callee != start_node:
            visited[callee] = 1
            queue.append((callee, 1))
    
    while queue:
        node, depth = queue.pop(0)
        for callee in get_calls_successors(g, node):
            if callee not in visited and callee not in exclude_nodes:
                visited[callee] = depth + 1
                queue.append((callee, depth + 1))
    return visited

# ── Find entry points ────────────────────────────────────────────────
entry_points = [
    (n, d) for n, d in graph.nodes(data=True)
    if d.get("kind") == "function" and is_entry_point(d.get("name", ""))
]
entry_point_nodes = {n for n, _ in entry_points}

# Categorize
do_funcs = [(n, d) for n, d in entry_points if " do_" in d.get("name", "")]
spell_funcs = [(n, d) for n, d in entry_points if " spell_" in d.get("name", "")]
spec_funcs = [(n, d) for n, d in entry_points if " spec_" in d.get("name", "")]
print(f"Entry points: {len(entry_points)} total")
print(f"  do_*:    {len(do_funcs)} command handlers")
print(f"  spell_*: {len(spell_funcs)} spell effects")
print(f"  spec_*:  {len(spec_funcs)} NPC special functions")

# ── Collect transitive callees via BFS ───────────────────────────────
cmd_callees: dict[str, dict[str, int]] = {}  # entry_name -> {node_id: min_depth}
all_callee_nodes: set[str] = set()
callee_min_depth: dict[str, int] = {}  # global min depth across all entry points

for node_id, node_data in entry_points:
    cmd = entry_point_name(node_data.get("name", "?"))
    callees = transitive_callees_bfs(graph, node_id, entry_point_nodes)
    cmd_callees[cmd] = callees
    for nid, depth in callees.items():
        all_callee_nodes.add(nid)
        callee_min_depth[nid] = min(callee_min_depth.get(nid, 999), depth)

# ── Depth distribution ───────────────────────────────────────────────
depth_dist = Counter(callee_min_depth.values())
direct_only = {nid for nid, d in callee_min_depth.items() if d == 1}
deeper = all_callee_nodes - direct_only

print(f"\nUnique callees (transitive): {len(all_callee_nodes)}")
print(f"  Direct (depth 1): {len(direct_only)}")
print(f"  Deeper (depth ≥2): {len(deeper)}")
print(f"\nDepth distribution (min depth across all entry points):")
for d in sorted(depth_dist.keys()):
    print(f"  depth {d}: {depth_dist[d]} callees")

# Per-entry-point expansion
direct_counts = [sum(1 for d in c.values() if d == 1) for c in cmd_callees.values()]
total_counts = [len(c) for c in cmd_callees.values()]
print(f"\nPer-entry-point callee counts:")
print(f"  Direct: mean={np.mean(direct_counts):.1f}, median={np.median(direct_counts):.0f}, max={max(direct_counts)}")
print(f"  Total:  mean={np.mean(total_counts):.1f}, median={np.median(total_counts):.0f}, max={max(total_counts)}")
# Out:
# Entry points: 633 total
#   do_*:    442 command handlers
#   spell_*: 160 spell effects
#   spec_*:  31 NPC special functions
#
# Unique callees (transitive): 853
#   Direct (depth 1): 559
#   Deeper (depth ≥2): 294
#
# Depth distribution (min depth across all entry points):
#   depth 1: 559 callees
#   depth 2: 194 callees
#   depth 3: 57 callees
#   depth 4: 28 callees
#   depth 5: 12 callees
#   depth 6: 2 callees
#   depth 7: 1 callees
#
# Per-entry-point callee counts:
#   Direct: mean=8.4, median=7, max=52
#   Total:  mean=122.2, median=95, max=418

# %% [markdown]
# ## Step 2: Resolve callee metadata and documentation
#
# For each callee node, resolve:
# - bare function name (from graph node attributes)
# - minimum call depth (from transitive BFS)
# - entity ID (via `get_body_eid`)
# - doc_db document (brief, details, rationale)
# - full documentation text for embedding

# %%
# ── Resolve callee info ──────────────────────────────────────────────
callee_info: dict[str, dict] = {}

for node_id in sorted(all_callee_nodes):
    vd = graph.nodes[node_id]
    full_sig = vd.get("name", node_id)
    name = bare_name(full_sig)

    # Resolve entity and doc
    eid = None
    doc = None
    doc_text = None
    try:
        eid = dg.get_body_eid(entity_db, node_id)
        entity = entity_db.get(eid)
        if entity:
            doc = doc_db.get_doc(eid.compound, entity.signature)
            if doc is None and eid.compound in doc_db:
                for _sig, d in doc_db[eid.compound].items():
                    if d.name == entity.name and d.brief:
                        doc = d
                        break
    except Exception:
        pass

    if doc:
        doc_text = doc.to_doxygen()

    callee_info[node_id] = {
        "name": name,
        "sig": full_sig,
        "min_depth": callee_min_depth.get(node_id, 999),
        "eid": str(eid) if eid else None,
        "brief": doc.brief if doc else None,
        "doc_text": doc_text,
        "doc_mid": doc.mid if doc else None,
    }

documented = sum(1 for v in callee_info.values() if v["brief"])
has_text = sum(1 for v in callee_info.values() if v["doc_text"])
depth1 = sum(1 for v in callee_info.values() if v["min_depth"] == 1)
print(f"Callees: {len(callee_info)}")
print(f"  At depth 1: {depth1}")
print(f"  At depth ≥2: {len(callee_info) - depth1}")
print(f"  With doc brief: {documented}")
print(f"  With full doc text: {has_text}")
print(f"  Undocumented: {len(callee_info) - documented}")
# Out:
# Callees: 853
#   At depth 1: 559
#   At depth ≥2: 294
#   With doc brief: 772
#   With full doc text: 839
#   Undocumented: 81

# %% [markdown]
# ## Step 3: Resolve embeddings via EmbeddingRefiner
#
# Reuse the `embeddings_cache.pkl` from the classify pipeline as a fast-path
# (keyed by `doc.mid`).  For callees not in cache, delegate to
# `refiner.generate_node_embedding_sbert(node_id)` — this resolves the entity,
# retrieves its doc text, and SBERT-encodes it in one call.

# %%
EMBEDDING_CACHE = CLUSTERING_DIR / "embeddings_cache.pkl"

# Load cached embeddings (keyed by doc.mid) — fast path
with open(EMBEDDING_CACHE, "rb") as f:
    all_embeddings: dict[str, np.ndarray] = pickle.load(f)

sample_dim = next(iter(all_embeddings.values())).shape[0]
print(f"Cached embeddings: {len(all_embeddings)} ({sample_dim}d)")

# ── Resolve callee embeddings ────────────────────────────────────────
callee_embeddings: dict[str, np.ndarray] = {}
missing_embedding: list[str] = []

# 1. Try cache first (keyed by doc.mid)
for node_id, info in callee_info.items():
    mid = info["doc_mid"]
    if mid and mid in all_embeddings:
        callee_embeddings[node_id] = all_embeddings[mid]
    else:
        missing_embedding.append(node_id)

print(f"Callees with cached embedding: {len(callee_embeddings)}")
print(f"Callees missing from cache: {len(missing_embedding)}")

# 2. For missing callees, use refiner (now backed by OpenAI)
encoded_via_refiner = 0
still_missing = []
for nid in missing_embedding:
    emb = refiner.generate_node_embedding_sbert(nid)
    if emb is not None:
        callee_embeddings[nid] = emb
        encoded_via_refiner += 1
    else:
        still_missing.append(nid)

no_embedding = still_missing
print(f"Encoded via OpenAI fallback: {encoded_via_refiner}")
print(f"Total with embedding: {len(callee_embeddings)}/{len(all_callee_nodes)}")
print(f"No embedding (undocumented): {len(no_embedding)}")

# ── Build name→node_id lookup (bare name → node_id) ─────────────────
name_to_nid: dict[str, str] = {}
for nid, info in callee_info.items():
    name_to_nid[info["name"]] = nid  # last-wins for the 1 duplicate

print(f"Bare name → node_id mappings: {len(name_to_nid)}")
# Out:
# Cached embeddings: 5293 (4096d)
# Callees with cached embedding: 839
# Callees missing from cache: 14
# Encoded via OpenAI fallback: 0
# Total with embedding: 839/853
# No embedding (undocumented): 14
# Bare name → node_id mappings: 852

# %% [markdown]
# ## Step 4: Load locked group assignments
#
# Read the `locked` lists from `capability_defs.json` to build definitive group
# memberships.  Functions are matched by bare name to the callee node IDs discovered
# in step 1.  Any locked names missing from the callee pool (or without embeddings)
# are reported.

# %%
# ── Build group assignments from locked lists ────────────────────────
group_members: dict[str, list[str]] = {}   # group → [node_id, ...]
group_embeddings: dict[str, dict[str, np.ndarray]] = {}  # for refiner
name_to_group: dict[str, str] = {}         # bare_name → group
unmatched_locked: list[tuple[str, str]] = []
no_emb_locked: list[tuple[str, str]] = []

for group_name, gdef in CAPABILITY_DEFS.items():
    locked_names = gdef.get("locked", [])
    nids = []
    embs = {}
    for fn_name in locked_names:
        name_to_group[fn_name] = group_name
        nid = name_to_nid.get(fn_name)
        if nid is None:
            unmatched_locked.append((fn_name, group_name))
            continue
        nids.append(nid)
        if nid in callee_embeddings:
            embs[nid] = callee_embeddings[nid]
        else:
            no_emb_locked.append((fn_name, group_name))
    group_members[group_name] = nids
    group_embeddings[group_name] = embs

total_locked = sum(len(gdef.get("locked", [])) for gdef in CAPABILITY_DEFS.values())
total_matched = sum(len(nids) for nids in group_members.values())
total_with_emb = sum(len(e) for e in group_embeddings.values())

print(f"Locked function names: {total_locked}")
print(f"Matched to callee pool: {total_matched}")
print(f"With embedding: {total_with_emb}")
print(f"Unmatched (not in callee pool): {len(unmatched_locked)}")
print(f"No embedding (undocumented): {len(no_emb_locked)}")

if unmatched_locked:
    print(f"\nUnmatched locked names:")
    for fn, g in unmatched_locked:
        print(f"  {g:25s}  {fn}")

# ── Build Subsystem objects for refiner ──────────────────────────────
subsystems: dict[str, Subsystem] = {}
for group_name in CAPABILITY_DEFS:
    nids = set(group_members.get(group_name, []))
    subsystems[group_name] = Subsystem(
        subsystem_id=group_name,
        name=group_name,
        nodes=nids,
        classification=GROUP_TYPE[group_name],
        description=CAPABILITY_DEFS[group_name]["desc"],
    )

print(f"\nGroup sizes (with embeddings):")
for t in TYPE_ORDER:
    groups = [(g, len(group_embeddings.get(g, {})))
              for g in CAPABILITY_DEFS if GROUP_TYPE[g] == t]
    for g, n in sorted(groups, key=lambda x: -x[1]):
        print(f"  [{t:14s}] {g:25s} {n:4d}")
# Out:
# Locked function names: 851
# Matched to callee pool: 851
# With embedding: 837
# Unmatched (not in callee pool): 0
# No embedding (undocumented): 14
#
# Group sizes (with embeddings):
#   [utility       ] string_ops                  41
#   [utility       ] flags                       34
#   [utility       ] text_editing                23
#   [utility       ] memory                      17
#   [utility       ] numerics                    13
#   [utility       ] arg_parsing                  8
#   [utility       ] imaging                      4
#   [infrastructure] persistence                 87
#   [infrastructure] admin                       10
#   [infrastructure] runtime                      9
#   [policy        ] state_rules                 54
#   [policy        ] attributes                  45
#   [policy        ] entity_lookup               34
#   [policy        ] visibility_rules            10
#   [projection    ] output                      56
#   [projection    ] display                     26
#   [domain        ] affects                     88
#   [domain        ] objects                     43
#   [domain        ] world_structure             37
#   [domain        ] movement                    34
#   [domain        ] skills_progression          31
#   [domain        ] clans                       30
#   [domain        ] combat                      25
#   [domain        ] npc_behavior                21
#   [domain        ] quests                      16
#   [domain        ] social                      10
#   [domain        ] notes                       10
#   [domain        ] economy                      9
#   [domain        ] magic                        6
#   [domain        ] pvp                          6

# %% [markdown]
# ## Step 5: Intra-group cohesion
#
# Compute the pairwise cosine similarity matrix within each group.
# Report average, min, and max off-diagonal similarity as cohesion metrics.
#
# The range plot below shows the full **min → max** spread of pairwise similarities
# within each group, with the mean marked.  Wide ranges indicate heterogeneous groups;
# tight ranges indicate consistent internal similarity.

# %%
# ── Intra-group similarity via refiner ────────────────────────────────
sim_matrices = refiner.calculate_similarity_matrices(group_embeddings)

cohesion_rows = []
print(f"{'Group':30s} {'Type':14s} {'N':>4s}  {'Avg':>5s}  {'Min':>5s}  {'Max':>5s}  {'Stability'}")
print("-" * 105)

for t in TYPE_ORDER:
    groups = [g for g in CAPABILITY_DEFS if GROUP_TYPE[g] == t and g in sim_matrices]
    for g in sorted(groups, key=lambda g: -len(group_embeddings.get(g, {}))):
        sm = sim_matrices[g]
        mat = sm["matrix"]
        n = mat.shape[0]
        if n < 2:
            continue
        mask = ~np.eye(n, dtype=bool)
        off_diag = mat[mask]
        avg, mn, mx = np.mean(off_diag), np.min(off_diag), np.max(off_diag)
        q25, q75 = np.percentile(off_diag, [25, 75])
        stab = CAPABILITY_DEFS[g].get("stability", "")
        cohesion_rows.append((g, t, n, avg, mn, mx, q25, q75, stab))
        print(f"  {g:28s} {t:14s} {n:4d}  {avg:.3f}  {mn:.3f}  {mx:.3f}  {stab}")

# ── Cohesion range plot ──────────────────────────────────────────────
# Sort by mean cohesion (ascending → weakest at top)
rows_sorted = sorted(cohesion_rows, key=lambda r: r[3])
names  = [r[0] for r in rows_sorted]
avgs   = [r[3] for r in rows_sorted]
mins   = [r[4] for r in rows_sorted]
maxs   = [r[5] for r in rows_sorted]
q25s   = [r[6] for r in rows_sorted]
q75s   = [r[7] for r in rows_sorted]
colors = [TYPE_COLORS[r[1]] for r in rows_sorted]

fig, ax = plt.subplots(figsize=(14, max(6, len(names) * 0.35)))
y_pos = np.arange(len(names))

# Thin line: full min→max range
for i in range(len(names)):
    ax.plot([mins[i], maxs[i]], [y_pos[i], y_pos[i]],
            color=colors[i], linewidth=1, alpha=0.5, solid_capstyle="round")

# Thick bar: IQR (25th–75th percentile)
for i in range(len(names)):
    ax.plot([q25s[i], q75s[i]], [y_pos[i], y_pos[i]],
            color=colors[i], linewidth=5, alpha=0.7, solid_capstyle="round")

# Dot: mean
ax.scatter(avgs, y_pos, color=colors, s=30, zorder=5, edgecolors="black", linewidths=0.5)

ax.set_yticks(y_pos)
ax.set_yticklabels(names, fontsize=8)
ax.set_xlabel("Pairwise cosine similarity (within group)")
ax.set_title("Group Cohesion — range of intra-group similarities\n"
             "thin line = min–max, thick bar = IQR (25th–75th pctl), dot = mean")
ax.set_xlim(-0.05, 1.05)

# Legend for type colours
from matplotlib.patches import Patch
legend_handles = [Patch(facecolor=TYPE_COLORS[t], label=t) for t in TYPE_ORDER]
ax.legend(handles=legend_handles, loc="lower right", fontsize=8)

plt.tight_layout()
plt.show()
# Out:
# Group                          Type              N    Avg    Min    Max  Stability
# ---------------------------------------------------------------------------------------------------------
#   string_ops                   utility          41  0.441  0.162  0.989  stable
#   flags                        utility          34  0.579  0.280  0.952  stable
#   text_editing                 utility          23  0.571  0.225  0.913  stable
#   memory                       utility          17  0.382  0.128  0.892  stable
#   numerics                     utility          13  0.456  0.236  0.758  stable
#   arg_parsing                  utility           8  0.469  0.285  0.935  stable
#   imaging                      utility           4  0.527  0.399  0.836  stable
#   persistence                  infrastructure   87  0.331  0.084  0.924  stable
#   admin                        infrastructure   10  0.392  0.160  0.800  stable
#   runtime                      infrastructure    9  0.415  0.173  0.692  stable
#   state_rules                  policy           54  0.436  0.169  0.921  stable
#   attributes                   policy           45  0.457  0.172  0.943  stable
#   entity_lookup                policy           34  0.549  0.264  0.950  stable
#   visibility_rules             policy           10  0.632  0.386  0.906  stable
#   output                       projection       56  0.383  0.123  0.930  stable
#   display                      projection       26  0.427  0.178  0.873  provisional
#   affects                      domain           88  0.528  0.217  0.949  stable
#   objects                      domain           43  0.448  0.127  0.917  likely_split
#   world_structure              domain           37  0.405  0.148  0.972  likely_split
#   movement                     domain           34  0.426  0.148  0.953  stable
#   skills_progression           domain           31  0.496  0.156  0.879  stable
#   clans                        domain           30  0.519  0.189  0.925  stable
#   combat                       domain           25  0.492  0.281  0.844  stable
#   npc_behavior                 domain           21  0.543  0.187  0.820  likely_split
#   quests                       domain           16  0.581  0.394  0.962  stable
#   social                       domain           10  0.437  0.199  0.857  stable
#   notes                        domain           10  0.585  0.372  0.768  stable
#   economy                      domain            9  0.422  0.245  0.856  stable
#   magic                        domain            6  0.550  0.431  0.629  stable
#   pvp                          domain            6  0.620  0.453  0.743  stable

# %% [markdown]
# ## Step 6: Inter-group similarity matrix
#
# Compute the mean centroid-to-centroid similarity between all group pairs.
# High inter-group similarity suggests overlapping definitions or candidates for merging.

# %%
# ── Compute group centroids ───────────────────────────────────────────
group_centroids: dict[str, np.ndarray] = {}
for g, embs in group_embeddings.items():
    if embs:
        group_centroids[g] = np.mean(np.stack(list(embs.values())), axis=0)

ordered_groups = [g for t in TYPE_ORDER for g in CAPABILITY_DEFS if GROUP_TYPE[g] == t and g in group_centroids]
centroid_matrix = np.stack([group_centroids[g] for g in ordered_groups])

# ── Inter-group cosine similarity ────────────────────────────────────
inter_sim = cosine_similarity(centroid_matrix, centroid_matrix)

fig, ax = plt.subplots(figsize=(14, 12))
im = ax.imshow(inter_sim, cmap="RdYlGn", vmin=0, vmax=1)
ax.set_xticks(range(len(ordered_groups)))
ax.set_yticks(range(len(ordered_groups)))
ax.set_xticklabels(ordered_groups, rotation=90, fontsize=8)
ax.set_yticklabels(ordered_groups, fontsize=8)
ax.set_title("Inter-group centroid similarity")
fig.colorbar(im, ax=ax, shrink=0.7)

# Annotate cells with values
for i in range(len(ordered_groups)):
    for j in range(len(ordered_groups)):
        if i != j and inter_sim[i, j] > 0.55:
            ax.text(j, i, f"{inter_sim[i,j]:.2f}", ha="center", va="center", fontsize=6, color="black")

plt.tight_layout()
plt.show()

# ── Report high inter-group similarities ─────────────────────────────
print("\nTop inter-group similarities (>0.55):")
pairs = []
for i, g1 in enumerate(ordered_groups):
    for j, g2 in enumerate(ordered_groups):
        if i < j and inter_sim[i, j] > 0.55:
            pairs.append((g1, g2, inter_sim[i, j]))
pairs.sort(key=lambda x: -x[2])
for g1, g2, s in pairs:
    print(f"  {s:.3f}  {g1:25s} ↔ {g2}")
# Out:
# Top inter-group similarities (>0.55):
#   0.833  output                    ↔ display
#   0.800  state_rules               ↔ attributes
#   0.795  state_rules               ↔ movement
#   0.783  display                   ↔ movement
#   0.781  admin                     ↔ output
#   0.779  state_rules               ↔ combat
#   0.770  attributes                ↔ skills_progression
#   0.769  string_ops                ↔ arg_parsing
#   0.769  entity_lookup             ↔ movement
#   0.764  memory                    ↔ persistence
#   0.760  state_rules               ↔ visibility_rules
#   0.753  combat                    ↔ magic
#   0.747  state_rules               ↔ skills_progression
#   0.747  combat                    ↔ skills_progression
#   0.744  state_rules               ↔ economy
#   0.739  runtime                   ↔ movement
#   0.735  visibility_rules          ↔ movement
#   0.732  runtime                   ↔ state_rules
#   0.727  state_rules               ↔ output
#   0.727  output                    ↔ social
#   0.727  magic                     ↔ skills_progression
#   0.725  entity_lookup             ↔ objects
#   0.720  persistence               ↔ output
#   0.720  attributes                ↔ economy
#   0.718  state_rules               ↔ quests
#   0.717  movement                  ↔ objects
#   0.713  state_rules               ↔ entity_lookup
#   0.711  movement                  ↔ world_structure
#   0.709  output                    ↔ movement
#   0.707  state_rules               ↔ objects
#   0.707  state_rules               ↔ npc_behavior
#   0.705  objects                   ↔ economy
#   0.704  combat                    ↔ movement
#   0.703  state_rules               ↔ display
#   0.703  attributes                ↔ combat
#   0.702  entity_lookup             ↔ display
#   0.702  state_rules               ↔ social
#   0.699  attributes                ↔ world_structure
#   0.694  movement                  ↔ quests
#   0.693  attributes                ↔ objects
#   0.693  attributes                ↔ output
#   0.691  skills_progression        ↔ quests
#   0.690  admin                     ↔ display
#   0.689  attributes                ↔ display
#   0.688  state_rules               ↔ clans
#   0.688  runtime                   ↔ output
#   0.688  runtime                   ↔ combat
#   0.684  magic                     ↔ affects
#   0.683  visibility_rules          ↔ display
#   0.682  affects                   ↔ objects
#   0.681  state_rules               ↔ affects
#   0.678  movement                  ↔ pvp
#   0.678  runtime                   ↔ npc_behavior
#   0.676  movement                  ↔ npc_behavior
#   0.675  affects                   ↔ movement
#   0.675  entity_lookup             ↔ social
#   0.674  runtime                   ↔ affects
#   0.674  combat                    ↔ affects
#   0.673  persistence               ↔ state_rules
#   0.673  string_ops                ↔ persistence
#   0.673  display                   ↔ world_structure
#   0.673  text_editing              ↔ output
#   0.671  attributes                ↔ movement
#   0.670  combat                    ↔ npc_behavior
#   0.670  combat                    ↔ quests
#   0.668  entity_lookup             ↔ world_structure
#   0.667  movement                  ↔ social
#   0.667  runtime                   ↔ social
#   0.667  entity_lookup             ↔ output
#   0.665  runtime                   ↔ display
#   0.665  attributes                ↔ entity_lookup
#   0.664  entity_lookup             ↔ quests
#   0.664  entity_lookup             ↔ npc_behavior
#   0.662  visibility_rules          ↔ entity_lookup
#   0.661  state_rules               ↔ world_structure
#   0.661  display                   ↔ skills_progression
#   0.658  entity_lookup             ↔ skills_progression
#   0.658  attributes                ↔ affects
#   0.657  movement                  ↔ skills_progression
#   0.657  persistence               ↔ objects
#   0.654  quests                    ↔ npc_behavior
#   0.653  economy                   ↔ quests
#   0.652  persistence               ↔ display
#   0.652  persistence               ↔ attributes
#   0.652  persistence               ↔ movement
#   0.652  persistence               ↔ social
#   0.650  string_ops                ↔ output
#   0.648  admin                     ↔ state_rules
#   0.647  runtime                   ↔ objects
#   0.644  display                   ↔ combat
#   0.644  objects                   ↔ quests
#   0.643  combat                    ↔ pvp
#   0.642  state_rules               ↔ pvp
#   0.641  entity_lookup             ↔ economy
#   0.641  admin                     ↔ social
#   0.641  state_rules               ↔ magic
#   0.641  output                    ↔ skills_progression
#   0.640  arg_parsing               ↔ entity_lookup
#   0.637  persistence               ↔ entity_lookup
#   0.636  admin                     ↔ runtime
#   0.634  economy                   ↔ world_structure
#   0.632  display                   ↔ social
#   0.632  runtime                   ↔ skills_progression
#   0.631  persistence               ↔ runtime
#   0.631  output                    ↔ combat
#   0.630  combat                    ↔ objects
#   0.629  output                    ↔ npc_behavior
#   0.628  display                   ↔ affects
#   0.628  display                   ↔ quests
#   0.627  persistence               ↔ admin
#   0.627  runtime                   ↔ attributes
#   0.626  attributes                ↔ quests
#   0.625  movement                  ↔ economy
#   0.623  visibility_rules          ↔ combat
#   0.623  display                   ↔ objects
#   0.619  clans                     ↔ pvp
#   0.619  social                    ↔ npc_behavior
#   0.618  skills_progression        ↔ npc_behavior
#   0.618  skills_progression        ↔ economy
#   0.618  runtime                   ↔ quests
#   0.617  output                    ↔ notes
#   0.617  affects                   ↔ skills_progression
#   0.616  arg_parsing               ↔ persistence
#   0.613  numerics                  ↔ attributes
#   0.613  skills_progression        ↔ objects
#   0.611  runtime                   ↔ entity_lookup
#   0.611  admin                     ↔ movement
#   0.610  skills_progression        ↔ social
#   0.609  visibility_rules          ↔ attributes
#   0.608  numerics                  ↔ world_structure
#   0.607  persistence               ↔ economy
#   0.607  social                    ↔ clans
#   0.605  output                    ↔ quests
#   0.603  imaging                   ↔ world_structure
#   0.603  entity_lookup             ↔ affects
#   0.602  magic                     ↔ movement
#   0.602  runtime                   ↔ visibility_rules
#   0.601  state_rules               ↔ notes
#   0.601  attributes                ↔ magic
#   0.600  display                   ↔ magic
#   0.598  objects                   ↔ npc_behavior
#   0.598  output                    ↔ affects
#   0.595  attributes                ↔ npc_behavior
#   0.595  visibility_rules          ↔ world_structure
#   0.594  persistence               ↔ world_structure
#   0.593  output                    ↔ objects
#   0.593  display                   ↔ npc_behavior
#   0.593  memory                    ↔ objects
#   0.592  social                    ↔ notes
#   0.592  visibility_rules          ↔ output
#   0.592  movement                  ↔ clans
#   0.592  flags                     ↔ state_rules
#   0.591  entity_lookup             ↔ combat
#   0.591  combat                    ↔ clans
#   0.591  objects                   ↔ world_structure
#   0.591  output                    ↔ magic
#   0.589  combat                    ↔ economy
#   0.589  output                    ↔ economy
#   0.587  runtime                   ↔ magic
#   0.587  runtime                   ↔ economy
#   0.586  arg_parsing               ↔ output
#   0.586  economy                   ↔ npc_behavior
#   0.585  movement                  ↔ notes
#   0.585  runtime                   ↔ notes
#   0.584  text_editing              ↔ admin
#   0.583  visibility_rules          ↔ objects
#   0.583  flags                     ↔ output
#   0.582  runtime                   ↔ pvp
#   0.582  magic                     ↔ npc_behavior
#   0.582  affects                   ↔ npc_behavior
#   0.581  magic                     ↔ quests
#   0.580  visibility_rules          ↔ skills_progression
#   0.580  display                   ↔ economy
#   0.579  persistence               ↔ clans
#   0.578  text_editing              ↔ movement
#   0.578  memory                    ↔ state_rules
#   0.578  persistence               ↔ affects
#   0.578  text_editing              ↔ display
#   0.577  admin                     ↔ attributes
#   0.575  attributes                ↔ social
#   0.574  visibility_rules          ↔ affects
#   0.572  affects                   ↔ economy
#   0.571  combat                    ↔ social
#   0.571  skills_progression        ↔ world_structure
#   0.571  affects                   ↔ social
#   0.571  memory                    ↔ world_structure
#   0.571  admin                     ↔ combat
#   0.571  persistence               ↔ quests
#   0.570  string_ops                ↔ entity_lookup
#   0.570  visibility_rules          ↔ quests
#   0.569  magic                     ↔ social
#   0.568  persistence               ↔ skills_progression
#   0.567  admin                     ↔ npc_behavior
#   0.567  objects                   ↔ social
#   0.567  pvp                       ↔ quests
#   0.566  string_ops                ↔ social
#   0.565  flags                     ↔ display
#   0.565  text_editing              ↔ social
#   0.565  visibility_rules          ↔ economy
#   0.565  output                    ↔ world_structure
#   0.564  admin                     ↔ notes
#   0.563  magic                     ↔ objects
#   0.563  social                    ↔ quests
#   0.562  visibility_rules          ↔ social
#   0.562  attributes                ↔ clans
#   0.561  entity_lookup             ↔ clans
#   0.560  admin                     ↔ quests
#   0.560  memory                    ↔ economy
#   0.560  memory                    ↔ attributes
#   0.560  runtime                   ↔ clans
#   0.559  visibility_rules          ↔ npc_behavior
#   0.559  persistence               ↔ npc_behavior
#   0.558  text_editing              ↔ persistence
#   0.557  display                   ↔ notes
#   0.555  arg_parsing               ↔ social
#   0.555  affects                   ↔ quests
#   0.555  admin                     ↔ entity_lookup
#   0.554  admin                     ↔ affects
#   0.553  string_ops                ↔ state_rules
#   0.553  quests                    ↔ world_structure
#   0.552  flags                     ↔ attributes
#   0.552  skills_progression        ↔ clans
#   0.551  numerics                  ↔ state_rules
#   0.551  string_ops                ↔ memory
#   0.551  string_ops                ↔ display

# %% [markdown]
# ## Step 7: Outlier detection & regroup suggestions
#
# Identify functions with low average similarity to their own group. Then check
# whether any neighbouring group would be a better semantic fit.
# Uses `EmbeddingRefiner.identify_outliers()` and `suggest_regroupings()`.

# %%
# ── Outlier detection ─────────────────────────────────────────────────
OUTLIER_THRESHOLD = 0.25  # fairly permissive — flags weakly-attached members
outliers = refiner.identify_outliers(subsystems, sim_matrices, threshold=OUTLIER_THRESHOLD)

print(f"Outliers (avg intra-group sim < {OUTLIER_THRESHOLD}): {len(outliers)}\n")

# Group outliers by their current group
outlier_by_group: dict[str, list] = defaultdict(list)
for o in outliers:
    outlier_by_group[o["current_subsystem"]].append(o)

for g in sorted(outlier_by_group, key=lambda g: -len(outlier_by_group[g])):
    members = outlier_by_group[g]
    print(f"[{g}] — {len(members)} outliers")
    for o in sorted(members, key=lambda x: x["average_similarity"]):
        info = callee_info.get(o["node_id"], {})
        brief = info.get("brief", "")
        b = f" — {brief[:55]}" if brief else ""
        print(f"  avg_sim={o['average_similarity']:.3f}  {o['name']:35s}{b}")

# ── Cross-group similarities & regroup suggestions ───────────────────
print(f"\n{'='*80}")
print("Computing cross-group similarities (this may take a moment)...")
cross_sims = refiner.calculate_cross_subsystem_similarities(group_embeddings)
suggestions = refiner.suggest_regroupings(outliers, cross_sims)

print(f"\nRegroup suggestions: {len(suggestions)}")
print(f"{'Name':35s} {'From':20s} {'To':20s} {'Δ sim':>7s}  {'Conf':>5s}")
print("-" * 95)
for s in suggestions[:40]:
    delta = s["suggested_similarity"] - s["current_similarity"]
    print(f"  {s['name']:33s} {s['current_subsystem']:20s} → {s['suggested_subsystem']:20s} "
          f"{delta:+.3f}  {s['confidence']:.2f}")
# Out:
# Outliers (avg intra-group sim < 0.25): 6
#
# [persistence] — 6 outliers
#   avg_sim=0.228  load_war_events                     — Loads war events from files and populates the war event
#   avg_sim=0.240  db_next_row                         — Advances to the next row in the SQLite query result.
#   avg_sim=0.241  db_rows_affected                    — Retrieves the number of rows affected by the last execu
#   avg_sim=0.246  db_close                            — Closes the database connection if it is open.
#   avg_sim=0.248  db_open                             — Opens a connection to the database.
#   avg_sim=0.250  save_war_events                     — Saves the events of each war to individual files.
#
# ================================================================================
# Computing cross-group similarities (this may take a moment)...
#
# Regroup suggestions: 4
# Name                                From                 To                     Δ sim   Conf
# -----------------------------------------------------------------------------------------------
#   load_war_events                   persistence          → clans                +0.165  1.00
#   save_war_events                   persistence          → clans                +0.143  0.87
#   db_rows_affected                  persistence          → affects              +0.044  0.26
#   db_close                          persistence          → pvp                  +0.028  0.17

# %% [markdown]
# ## Step 8: Per-group detail — members sorted by intra-group similarity
#
# For manual review: list each group's members sorted by their average similarity
# to fellow group members.  Functions near the bottom of each group are the most
# "edge-case" members worth eyeballing.

# %%
# ── Per-group member detail ───────────────────────────────────────────
# Set SHOW_GROUP to a group name (or None for all, or a type name for a category)
SHOW_GROUP = None  # e.g. "affects", "combat", "domain", None for all

def member_similarities(sim_data):
    """Return list of (node_id, avg_sim_to_peers)."""
    nids = sim_data["node_ids"]
    mat = sim_data["matrix"]
    n = len(nids)
    result = []
    for i, nid in enumerate(nids):
        if n > 1:
            peer_sims = [mat[i, j] for j in range(n) if i != j]
            result.append((nid, np.mean(peer_sims)))
        else:
            result.append((nid, 1.0))
    return sorted(result, key=lambda x: -x[1])

groups_to_show = []
if SHOW_GROUP is None:
    groups_to_show = list(CAPABILITY_DEFS.keys())
elif SHOW_GROUP in TYPE_ORDER:
    groups_to_show = [g for g in CAPABILITY_DEFS if GROUP_TYPE[g] == SHOW_GROUP]
elif SHOW_GROUP in CAPABILITY_DEFS:
    groups_to_show = [SHOW_GROUP]
else:
    print(f"Unknown group or type: {SHOW_GROUP}")

for g in groups_to_show:
    if g not in sim_matrices:
        continue
    sm = sim_matrices[g]
    ranked = member_similarities(sm)
    n = len(ranked)
    if n == 0:
        continue
    avg_all = np.mean([s for _, s in ranked])
    print(f"\n{'='*80}")
    print(f"[{GROUP_TYPE[g]}/{g}] — {n} members, avg cohesion {avg_all:.3f}")
    print(f"  {'avg_sim':>7s}  {'name':40s}  brief")
    print(f"  {'-'*7}  {'-'*40}  {'-'*40}")
    for nid, avg_s in ranked:
        info = callee_info.get(nid, {})
        name = info.get("name", nid[:12])
        brief = info.get("brief", "")
        b = brief[:55] if brief else ""
        marker = " ◄" if avg_s < 0.15 else ""
        print(f"  {avg_s:7.3f}  {name:40s}  {b}{marker}")
# Out:
# ================================================================================
# [domain/combat] — 25 members, avg cohesion 0.492
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.558  damage                                    Calculates and applies damage from an attack to a victi
#     0.557  one_hit                                   Performs a single attack action from one character to a
#     0.534  multi_hit                                 Performs multiple attack actions for a character during
#     0.528  check_dodge                               Checks whether a character successfully dodges an attac
#     0.527  check_parry                               Checks whether a character successfully parries an atta
#     0.525  raw_kill                                  Handles the death of a character by stopping combat, tr
#     0.523  dragon                                    Executes a dragon's special attack if conditions are me
#     0.519  check_shblock                             Checks if a character successfully blocks an attack wit
#     0.515  fireball_bash                             Calculates and applies a fireball bash effect that may
#     0.514  trip                                      Attempts to trip a victim character, applying effects a
#     0.511  check_blur                                Checks whether a character successfully evades an attac
#     0.507  mob_hit                                   Handles attack actions for a mobile character, includin
#     0.504  set_fighting                              Initiates combat between two characters.
#     0.492  kill_off                                  Handles the death of a character, including logging, ex
#     0.492  update_pos                                Updates the position of a character based on their hit
#     0.488  defense_heal                              Applies a defensive heal to a character based on a chan
#     0.480  check_dual_parry                          Checks for a successful dual-wield parry from the off-h
#     0.480  stop_fighting                             Stops a character from fighting and updates their posit
#     0.449  death_cry                                 Handles the death cry event for a character, including
#     0.447  xp_compute                                Calculates experience points (XP) for a character after
#     0.445  group_gain                                Calculates and distributes experience points among grou
#     0.435  prepare_char                              Prepares a character for a duel by relocating them to t
#     0.430  make_corpse                               Creates a corpse object from a character, transferring
#     0.428  get_weapon_skill                          Determines the skill type associated with the weapon a
#     0.400  war_score_adjust                          Adjusts the score of a clan in a war and handles defeat
#
# ================================================================================
# [domain/magic] — 6 members, avg cohesion 0.550
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.582  obj_cast_spell                            Performs spell casting at targets using a magical objec
#     0.575  saves_spell                               Computes whether a character successfully makes a savin
#     0.565  say_spell                                 Generates and displays a mystical spell incantation mes
#     0.560  chain_spell                               Executes a chain spell that damages multiple targets in
#     0.541  dispel_char                               Dispel a list of spells from a character using dispel m
#     0.479  comp_spells                               Compares two spells for sorting by level and name.
#
# ================================================================================
# [domain/affects] — 88 members, avg cohesion 0.528
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.609  affect::remove_matching_from_char         Removes matching affects from a character's affect list
#     0.606  affect::copy_to_char                      Applies an affect to a character.
#     0.599  affect::iterate_over_char                 Iterates over a character's affects and applies a funct
#     0.595  affect::join_to_char                      Adds an affect to a character and removes duplicates.
#     0.593  affect::remove_type_from_char             Removes affects of a specific type from a character.
#     0.592  affect::find_on_char                      Finds an affect of a specified type on a character.
#     0.592  affect::add_type_to_char                  Adds an affect of a specified type to a character, hand
#     0.591  affect::list_char                         Retrieves the list of affects on a character.
#     0.585  affect::remove_matching_from_obj          Removes matching Affect objects from an object's affect
#     0.585  affect::modify_obj                        Updates the state of an object's affect list.
#     0.583  affect::remove_type_from_obj              Removes all affects of a specific type from an object's
#     0.582  affect::join_to_obj                       Integrates an Affect into an Object's affect list.
#     0.581  affect::find_on_obj                       Finds an affect of a specified type on a given object.
#     0.581  affect::copy_to_obj                       Adds an affect to an object's affect list.
#     0.578  affect::remove_marked_from_char           Removes affects with a marked attribute from a characte
#     0.577  affect::remort_affect_modify_char         Modifies a character's attributes based on remort affec
#     0.576  affect::dedup_in_list                     Removes duplicate affects from a list and accumulates t
#     0.576  affect::remove_all_from_char              Removes all affects with a specified permanence from a
#     0.576  affect::sort_char                         Sorts the list of Affect objects associated with a Char
#     0.575  check_dispel_obj                          Attempts to dispel affects on an object based on specif
#     0.574  affect::modify_char                       Updates character attributes based on an affect.
#     0.574  affect::copy_flags_to_char                Transforms a bitvector into a set of affects or defense
#     0.573  affect::iterate_over_obj                  Iterates over an object's affect list and applies a fun
#     0.573  affect::remove_all_from_obj               Removes all Affect objects with a specified 'permanent'
#     0.571  affect_fn_dispel_char                     Attempts to dispel an affect from a character based on
#     0.571  affect_fn_dispel_obj                      Attempts to dispel an affect on an object based on cert
#     0.570  affect::list_obj                          Retrieves the affect list associated with an object.
#     0.568  affect::exists_on_char                    Checks if a specific affect type exists on a character.
#     0.563  affect::remove_marked_from_obj            Removes marked Affect objects from an object's affect l
#     0.562  affect::exists_on_obj                     Checks if an affect of a specified type exists on an ob
#     0.561  affect::copy_to_room                      Adds an affect to a room and updates the room's state.
#     0.557  check_dispel_char                         Attempts to dispel all affects of a specified type from
#     0.557  affect::list_room                         Retrieves the list of affects associated with a room.
#     0.556  affect::add_perm_to_char                  Adds a permanent affect of a specified type to a charac
#     0.555  rem_raff_affect                           Removes remort affects from a character based on the af
#     0.553  affect::sort_obj                          Sorts the list of Affect objects associated with an Obj
#     0.552  affect::remove_matching_from_list         Removes matching Affect objects from a doubly linked li
#     0.550  affect::iterate_over_room                 Iterates over the affects of a room and applies a funct
#     0.550  affect::parse_flags                       Performs error checking and modifies an Affect struct b
#     0.550  affect::remove_matching_from_room         Removes affects from a room that match a given pattern.
#     0.546  affect::fn_fade_spell                     Decreases the duration and potentially the level of an
#     0.546  undo_spell                                Attempts to undo or dispel a specific affect of a given
#     0.541  affect::modify_room                       Updates the room's state based on changes to its affect
#     0.539  affect::iterate_over_list                 Iterates over a linked list of Affect objects and appli
#     0.538  affect::in_cache                          Checks if a specific affect type is present in the char
#     0.537  raff_add_to_char                          Adds a remort affect to a character based on a given af
#     0.534  affect::remove_from_list                  Removes an Affect from a doubly linked list.
#     0.532  affect::sort_room                         Sorts the list of Affect objects in a Room.
#     0.530  roll_raffects                             Assigns multiple random remort affects to a character.
#     0.527  affect::find_in_list                      Finds an affect of a specified type in a linked list.
#     0.527  get_affect_evolution                      Determines the highest evolution level of a specific af
#     0.525  roll_mod                                  Selects and applies a random affect modification to an
#     0.524  affect::copy_to_list                      Copies an Affect object and inserts it into a doubly li
#     0.522  gem::compile_effects                      Compiles and applies gem effects to an object.
#     0.517  affect::print_cache                       Generates a formatted string representing the affect ca
#     0.515  affect::comparator_permanent              Compares the 'permanent' attribute of two Affect object
#     0.514  affect::checksum                          Calculates a checksum for an Affect structure.
#     0.514  HAS_RAFF                                  Checks if a character has a specific remort affect flag
#     0.514  affect::swap                              Swaps the contents of two Affect objects.
#     0.513  affect::comparator_type                   Compares two Affect objects based on their type.
#     0.512  affect::enchanted_obj                     Determines if an object is enchanted.
#     0.511  room_update                               Updates all rooms by processing their affects.
#     0.511  roll_one_raff                             Assigns a random remort affect to a character.
#     0.503  affect_callback_weaken_bonewall           Handles the weakening of a bone wall affect upon a hit.
#     0.500  fix_blank_raff                            Fixes blank remort affects for a character.
#     0.494  affect::clear_list                        Recursively clears a linked list of Affect objects.
#     0.494  affect::add_racial_to_char                Adds racial affects and modifiers to a character.
#     0.489  enhance_blade                             Enhances a weapon object with a specified affect if it
#     0.488  affect::sort_list                         Sorts a linked list of Affect objects using a comparato
#     0.485  affect::lookup                            Retrieves the table entry associated with a given affec
#     0.482  affect::comparator_mark                   Compares two Affect objects based on their mark attribu
#     0.482  affect::insert_in_list                    Inserts an Affect object into a doubly linked list.
#     0.481  spread_plague                             Distributes a plague affect to characters in a room bas
#     0.478  check_cond                                Checks and applies damage to an object based on charact
#     0.478  affect::comparator_duration               Compares the duration of two Affect objects.
#     0.476  affect::bit_to_type                       Converts a bit flag to its corresponding affect type.
#     0.466  shock_effect                              Applies a shock effect recursively to game entities suc
#     0.460  cold_effect                               Applies a cold effect to a specified target, which can
#     0.456  affect::checksum_list                     Calculates a checksum for a list of Affect structures.
#     0.454  poison_effect                             Applies poison effects recursively to rooms, characters
#     0.441  acid_effect                               Applies acid effects recursively to game entities such
#     0.437  check_protection_aura                     Checks and applies protection aura effects on a victim
#     0.437  fire_effect                               Handles the fire effect on various targets such as room
#     0.419  affect::Affect::bitvector                 Returns a Flags object representing the current bitvect
#     0.404  affect_loc_name                           Returns a string representation of a location effect.
#     0.398  affect_index_lookup                       Finds the index of an affect table entry matching a giv
#     0.345  affect::attr_location_check               Checks if the given attribute location is valid and ret
#     0.339  raff_lookup                               Finds the index of a raff based on its ID.
#
# ================================================================================
# [domain/movement] — 34 members, avg cohesion 0.426
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.539  char_from_room                            Removes a character from its current room and updates a
#     0.506  char_to_room                              Moves a character into a specified room, handling null
#     0.500  Room::remove_char                         Removes a character from the room and updates associate
#     0.488  Room::add_char                            Adds a character to the room and updates related area a
#     0.483  move_char                                 Handles moving a character from one room to another wit
#     0.483  exits_in                                  Displays rooms and portals with exits leading into the
#     0.477  extract_char                              Removes a character from the game world, handling clean
#     0.472  access_room                               Determines the accessible room via a specified exit.
#     0.472  get_random_room                           Selects and returns a random suitable room for a charac
#     0.472  get_scatter_room                          Selects a suitable random room for scattering a charact
#     0.455  Area::remove_char                         Removes a character from the area, updating NPC counts
#     0.455  char_in_duel_room                         Checks if a character is in a duel room.
#     0.454  char_in_darena_room                       Checks if a character is in a duel arena room.
#     0.452  find_exit                                 Determines the exit door index in a room based on a giv
#     0.452  obj_from_room                             Removes an Object from its current Room.
#     0.445  scan_list                                 Iterates through all characters in a specified room and
#     0.439  checkexits                                Generates a string listing all exits of a given room th
#     0.438  obj_to_room                               Places an object into a specified room, handling specia
#     0.435  nuke_pets                                 Removes a character's pet and any associated followers
#     0.430  World::remove_char                        Removes a character from the world's character list.
#     0.429  get_position                              Determines the current position of a character.
#     0.423  find_door                                 Determines the door index corresponding to a given dire
#     0.414  checkexitstoroom                          Generates a formatted string for exits between a room a
#     0.402  room_pair                                 Generates a formatted string representing the relations
#     0.396  set_tail                                  Sets or clears a tailing relationship between character
#     0.396  find_path                                 Finds the shortest path from a starting room to a targe
#     0.384  stop_follower                             Stops a character from following their current master a
#     0.380  recall                                    Handles the recall process for a character, teleporting
#     0.361  make_pet                                  Creates a pet character and establishes it as a followe
#     0.353  get_warp_loc_string                       Retrieves the warp location description from an object.
#     0.341  IS_OUTSIDE
#     0.313  IS_FLYING
#     0.266  Exit::rev_dir                             Returns the reverse direction for a given direction ind
#     0.262  Exit::keyword                             Retrieves the keyword associated with the Exit object.
#
# ================================================================================
# [domain/skills_progression] — 31 members, avg cohesion 0.496
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.603  get_learned                               Retrieves the learned level of a skill for a character.
#     0.595  get_skill_level                           Calculates the skill level for a character based on ski
#     0.582  get_evolution                             Calculates the evolution level of a character for a giv
#     0.576  set_evolution                             Sets the evolution level for a specific skill type for
#     0.554  set_learned                               Sets the learned value of a skill for a character.
#     0.554  get_weapon_learned                        Calculates the weapon skill level for a character.
#     0.545  get_random_skill                          Selects a random skill or spell that the character can
#     0.540  can_evolve                                Determines if a character can evolve a specified skill
#     0.535  get_skill_cost                            Calculates the mana cost for a given skill type for a c
#     0.534  group_add                                 Adds a specified skill or group to a character, optiona
#     0.528  find_spell                                Finds a spell that the character can cast based on a pr
#     0.518  prac_by_key                               Displays a list of skills and spells sorted by percenta
#     0.518  check_improve                             Checks and improves a character's skill based on succes
#     0.514  evolve_list                               Generates and displays a list of skills and spells that
#     0.507  get_usable_level                          Calculates the usable level of a character.
#     0.494  prac_by_group                             Displays a list of skills and spells known by the chara
#     0.492  advance_level                             Advances a character's level, updating their attributes
#     0.491  demote_level                              Demotes a character's level by reducing their attribute
#     0.491  gn_add                                    Recursively adds a group and its associated spells to a
#     0.489  completed_group                           Checks whether a character has completed a specified sk
#     0.481  list_extraskill                           Displays a list of extraclass remort skills for a chara
#     0.481  get_holdable_level                        Calculates the holdable level for a character.
#     0.481  npc_advance_level                         Advances the level of a non-player character (NPC).
#     0.476  select_pose                               Selects a pose for a character based on their class and
#     0.466  exp_per_level                             Calculates the experience points required per level for
#     0.435  skill::lookup                             Looks up the skill type based on a prefix match with th
#     0.435  skill::from_int                           Converts an integer to a corresponding skill type.
#     0.432  gain_exp                                  Increases a character's experience points and handles l
#     0.424  skill::num_skills                         Returns the number of skills available.
#     0.333  guild_lookup                              Looks up a guild by name using a prefix match.
#     0.277  group_lookup                              Finds the index of a group by its name.
#
# ================================================================================
# [domain/objects] — 43 members, avg cohesion 0.448
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.543  obj_to_char                               Transfers an object to a character's inventory.
#     0.525  obj_from_char                             Removes an object from the character's possession.
#     0.515  obj_to_strongbox                          Adds an object to a character's strongbox.
#     0.509  obj_to_locker                             Adds an object to a character's locker.
#     0.507  obj_from_strongbox                        Removes an object from a character's strongbox.
#     0.505  extract_obj                               Removes an object and its contents from the game world.
#     0.503  obj_to_keeper                             Inserts an object into a character's inventory, handlin
#     0.500  obj_from_locker                           Removes an object from a character's locker.
#     0.496  obj_to_obj                                Moves an object into another object, handling special c
#     0.494  obj_from_obj                              Removes an object from its containing object.
#     0.489  equip_char                                Equips an object to a character at a specified wear loc
#     0.489  remove_obj                                Removes an object from a character's equipment at a spe
#     0.484  get_obj                                   Handles the process of a character picking up an object
#     0.475  wear_obj                                  Handles the process of wearing, wielding, or holding an
#     0.474  unequip_char                              Unequips an object from a character, updating attribute
#     0.474  spill_contents                            Distributes the contents of an object to appropriate lo
#     0.471  get_locker_number                         Calculates the total number of objects in a character's
#     0.471  vape_ceq_recursive                        Recursively vaporizes clan equipment objects, removing
#     0.466  get_obj_number                            Calculates the total number of objects contained within
#     0.465  destroy_obj                               Destroys a game object and handles its contents.
#     0.462  can_loot                                  Determines if a character can loot a specific object.
#     0.460  vape_ceq                                  Vaporizes a character's carried clan equipment objects
#     0.458  gem::inset                                Moves a gem object into another object.
#     0.452  will_fit                                  Determines if an object can fit inside a container.
#     0.445  setup_obj                                 Configures a game object based on its type and an optio
#     0.440  count_users                               Counts the number of users interacting with a specific
#     0.440  generate_eq                               Generates and initializes a new equipment object based
#     0.439  obj_repair                                Repairs a specified object, either by a character in th
#     0.439  get_obj_weight                            Calculates the total weight of an object, including its
#     0.432  get_owner                                 Retrieves the owner description of a specified object f
#     0.429  recursive_clone                           Recursively clones an object and all its contained obje
#     0.422  add_base_stats                            Adds base statistics to an Object based on its type, le
#     0.421  clone_object                              Duplicates an object, excluding its contents.
#     0.416  create_object                             Creates and initializes a new game object from a protot
#     0.413  get_true_weight                           Calculates the true weight of an object, including all
#     0.392  item_type_name                            Retrieves the name of an item's type based on the objec
#     0.391  is_anvil_owner                            Determines if the specified character is the owner of t
#     0.388  has_modified_contents                     Checks if an object contains modified contents.
#     0.382  forge_flag                                Handles forging of weapon flags on a weapon object by a
#     0.344  anvil_owner_name                          Retrieves the owner's name from a private anvil object.
#     0.330  get_base_name                             Retrieves a base name string for a given equipment type
#     0.307  get_legendary_name                        Generates a legendary name based on the equipment type.
#     0.291  ObjectValue::value                        Retrieves the stored integer value.
#
# ================================================================================
# [domain/social] — 10 members, avg cohesion 0.437
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.535  check_channel_social                      Checks if a social channel command matches a social act
#     0.514  check_social                              Checks if a social command matches the input and execut
#     0.458  social_lookup                             Finds a social interaction by its name.
#     0.454  remove_social                             Removes a social entry from the social table by name.
#     0.436  channel                                   Handles communication through various channels for a ch
#     0.427  insert_social                             Inserts a Social object into a sorted list alphabetical
#     0.409  ignore_offline                            Toggles the ignore status of a character based on the p
#     0.384  config_censor                             Configures censorship settings for a character based on
#     0.382  count_socials                             Counts the number of social objects in a linked list.
#     0.376  send_to_clan                              Sends a message to all members of a specified clan.
#
# ================================================================================
# [domain/economy] — 9 members, avg cohesion 0.422
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.466  get_cost                                  Calculates the cost of an object in a shop transaction.
#     0.455  deduct_cost                               Deducts a specified cost from a character's currency.
#     0.452  create_money                              Creates a new game object representing a specified amou
#     0.436  gold_weight
#     0.423  find_money                                Updates the banked gold and silver for a player charact
#     0.420  silver_weight
#     0.409  find_keeper                               Finds an appropriate shopkeeper NPC in the character's
#     0.370  Shop::is_questshop                        Checks if the shop is a quest shop.
#     0.365  Auction::is_participant                   Checks if the given object is the item being auctioned.
#
# ================================================================================
# [domain/clans] — 30 members, avg cohesion 0.519
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.619  war_join                                  Adds a clan to a war as either a challenger or defender
#     0.612  clan_in_war                               Checks if a clan is involved in a specified war.
#     0.606  get_same_war                              Finds an ongoing war involving both specified clans.
#     0.605  clan_opponents                            Determines if two clans are opponents in an ongoing war
#     0.602  clan_is_challenger                        Determines if a clan is a challenger in a given war.
#     0.601  clan_at_war                               Determines if a clan is currently engaged in any ongoin
#     0.592  war_unjoin                                Removes or updates a clan's participation in a war.
#     0.580  war_start                                 Initiates a war between two clans.
#     0.580  defeat_clan                               Handles the defeat of a clan in a war.
#     0.570  war_stop                                  Stops an ongoing war and updates the scores of particip
#     0.544  war_power_adjust                          Adjusts the power of a clan based on ongoing wars and e
#     0.544  war_win                                   Handles the conclusion of a war with a victory.
#     0.531  war_kill                                  Handles the event of a character killing another charac
#     0.505  is_clan                                   Checks if a character belongs to a clan.
#     0.497  fix_war                                   Reorganizes and updates the state of a given war.
#     0.492  save_clan_table                           Saves the current state of all clans to the database.
#     0.488  remove_clan                               Removes a clan from the clan list by name.
#     0.487  war_is_full                               Checks if a side of the war is fully populated with par
#     0.483  calc_cp                                   Calculates the clan power based on various clan attribu
#     0.476  append_clan                               Appends a Clan object to the end of a linked list of cl
#     0.475  clan_vnum_lookup                          Finds a clan by a given virtual number (vnum).
#     0.475  count_clans                               Counts the number of clans in a linked list.
#     0.471  get_war_index                             Retrieves the index of a specific War instance in the w
#     0.470  war_lookup                                Retrieves a war from the list by its sequential number.
#     0.464  compare_clans                             Compares two Clan objects by their names for sorting pu
#     0.462  clan_lookup                               Finds a clan by its name prefix.
#     0.457  count_clan_members                        Counts the number of members in a specified clan with a
#     0.435  rec_event                                 Records an event in the specified war.
#     0.428  append_war                                Appends a War object to the end of a doubly linked list
#     0.420  Room::clan                                Retrieves the clan associated with the room.
#
# ================================================================================
# [domain/pvp] — 6 members, avg cohesion 0.620
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.688  remove_duel                               Removes a duel from the linked list and cleans up assoc
#     0.653  get_duel                                  Retrieves the duel associated with a character if valid
#     0.634  clear_arena                               Clears all non-immortal characters from the specified d
#     0.608  duel_kill                                 Handles the process of killing a victim in a duel, relo
#     0.575  append_duel                               Appends a Duel to the end of the duel table.
#     0.560  get_random_arena                          Selects a random duel arena from the available arenas.
#
# ================================================================================
# [domain/quests] — 16 members, avg cohesion 0.581
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.652  quest_info                                Provides quest-related information to a character.
#     0.627  generate_skillquest                       Generates a skill quest for a character by creating que
#     0.624  generate_quest                            Generates a quest for a character by selecting a suitab
#     0.624  generate_skillquest_mob                   Generates a skill quest mobile character and associated
#     0.622  squest_info                               Displays information about the current skill quest for
#     0.604  find_squestmaster                         Finds the special quest master character in the current
#     0.597  quest_cleanup                             Resets the quest-related data for a character.
#     0.591  find_questmaster                          Finds a questmaster character in the same room as the g
#     0.582  generate_skillquest_obj                   Generates a skill quest object for a character at a spe
#     0.581  sq_cleanup                                Cleans up and resets quest-related data for a character
#     0.569  squestobj_to_squestmob                    Handles the completion of a skill quest when a characte
#     0.560  quest_usage                               Displays usage information for QUEST commands to a char
#     0.555  IS_QUESTOR
#     0.541  has_enough_qps                            Checks if a character has enough quest points.
#     0.500  IS_SQUESTOR
#     0.461  quest_level_diff                          Determines if the character and monster levels are with
#
# ================================================================================
# [domain/npc_behavior] — 21 members, avg cohesion 0.543
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.641  mprog_entry_trigger                       Triggers entry mob programs for a character if conditio
#     0.629  mprog_driver                              Processes a list of mobile program commands triggered b
#     0.626  mprog_act_trigger                         Triggers an action program for a non-player character (
#     0.622  mprog_percent_check                       Checks and executes mobile program commands based on a
#     0.602  mprog_buy_trigger                         Triggers buy-related mob programs when a character inte
#     0.587  mprog_wordlist_check                      Checks a character's mobile programs for keyword or phr
#     0.580  mprog_speech_trigger                      Processes speech triggers for NPCs in the same room bas
#     0.579  mprog_bribe_trigger                       Handles the bribe trigger event for a mobile character,
#     0.579  mprog_greet_trigger                       Triggers greeting mob programs for NPCs in the same roo
#     0.576  mprog_give_trigger                        Handles the 'give' trigger for a mobile NPC when it rec
#     0.576  mprog_process_cmnd                        Processes a command string by expanding variables and e
#     0.571  mprog_tick_trigger                        Checks and potentially triggers mob programs based on a
#     0.570  mprog_death_trigger                       Handles death-related triggers and effects for a charac
#     0.565  mprog_translate                           Translates a character code into a string representatio
#     0.553  mprog_do_ifchck                           Performs evaluation of conditional checks within a game
#     0.552  mprog_process_if                          Handles control flow logic for MOBprograms, processing
#     0.430  hunt_victim                               Handles the hunting behavior of an NPC character to pur
#     0.418  mprog_seval                               Evaluates a string comparison operation based on a spec
#     0.417  animate_mob                               Creates and summons a mobile creature (mob) as a pet or
#     0.377  mprog_veval                               Evaluates a comparison or bitwise operation between two
#     0.350  mprog_next_command                        Extracts the next line from a multi-line string.
#
# ================================================================================
# [policy/state_rules] — 54 members, avg cohesion 0.436
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.507  IS_IMMORTAL
#     0.506  IS_KILLER
#     0.493  IS_HERO
#     0.491  IS_SPECIAL                                Determines if a character is considered 'special'.
#     0.485  Character::is_npc                         Determines if the character is a non-player character (
#     0.485  is_safe_char                              Determines whether it is safe for a character to attack
#     0.484  is_same_clan                              Determines if two characters belong to the same clan.
#     0.478  IS_THIEF
#     0.474  char_at_war                               Determines if a character is engaged in any ongoing war
#     0.470  IS_REMORT
#     0.467  is_safe_spell                             Determines if casting a spell on a target character is
#     0.466  is_safe                                   Determines whether an attack from one character to anot
#     0.464  is_ignoring                               Checks if a character is ignoring another character.
#     0.462  CAN_WEAR
#     0.461  is_safe_drag                              Checks whether it is safe to push or drag a victim char
#     0.460  IS_GOOD
#     0.460  clan_eq_ok                                Determines if a character can interact with a clan-owne
#     0.460  IS_HEROIC
#     0.459  IS_EVIL
#     0.454  IS_NEUTRAL
#     0.450  char_in_duel                              Determines if a character is currently engaged in a due
#     0.446  help_mob                                  Checks if a character is improperly assisting or hinder
#     0.446  char_in_darena                            Checks if a character is in a duel arena.
#     0.443  check_attack_ok                           Checks whether a character can initiate an attack on a
#     0.443  Character::has_cgroup                     Checks if the character has any of the specified cgroup
#     0.442  check_killer                              Checks and updates a character's status to become a kil
#     0.442  IS_IMM_GROUP
#     0.442  char_opponents                            Determines if two characters are opponents in an ongoin
#     0.441  HAS_RAFF_GROUP                            Checks if a character has a specific raffect group.
#     0.440  CHARTYPE_TEST
#     0.435  check_pulse                               Checks and updates a character's status during a pulse,
#     0.431  IS_AWAKE
#     0.429  IS_IMP
#     0.427  CAN_FLY
#     0.425  is_same_group                             Determines if two characters belong to the same group.
#     0.424  pers_eq_ok                                Checks if a character can legitimately use a personaliz
#     0.423  check_all_cond                            Checks and updates the condition of all equipment worn
#     0.422  CHARTYPE_MATCH
#     0.422  CAN_USE_RSKILL                            Determines if a character can use a remort skill.
#     0.422  acceptable_sac                            Determines if an object is an acceptable sacrifice for
#     0.417  gain_condition                            Adjusts a character's condition based on the specified
#     0.415  HAS_EXTRACLASS                            Checks if a character has access to an extra class skil
#     0.415  IS_HEAD
#     0.412  can_drop_obj                              Determines if a character can drop a specified object.
#     0.401  align                                     Changes a character's alignment if conditions are met.
#     0.397  is_room_owner                             Checks if the specified character is the owner of the g
#     0.384  Descriptor::is_playing                    Checks if the descriptor is currently in the playing st
#     0.380  DAZE_STATE
#     0.369  OUTRANKS
#     0.367  WAIT_STATE
#     0.360  add_follower                              Assigns a new follower to a character, establishing a m
#     0.355  RANK
#     0.354  from_box_ok                               Determines if an object can be taken from a specified c
#     0.319  die_follower                              Handles the process of a character dying and properly r
#
# ================================================================================
# [policy/visibility_rules] — 10 members, avg cohesion 0.632
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.737  can_see_in_room                           Determines whether a character can see in a specific ro
#     0.673  check_blind                               Checks if a character can see, considering immortality
#     0.672  can_see_char                              Determines if one character can see another character.
#     0.655  can_see_room                              Determines whether a character can see a specific room
#     0.654  can_see_obj                               Determines if a character can see a specific object.
#     0.619  is_blinded                                Determines if a character is blinded by any affect.
#     0.606  can_see_who                               Determines if a character can see another character in
#     0.584  Room::is_very_dark                        Determines if the room is very dark.
#     0.580  Room::is_dark                             Determines if the room is dark.
#     0.540  Room::is_private                          Determines if the room is private.
#
# ================================================================================
# [policy/attributes] — 45 members, avg cohesion 0.457
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.546  GET_ATTR_HITROLL
#     0.545  GET_ATTR_DAMROLL
#     0.509  GET_ATTR_CHR
#     0.506  GET_ATTR_AC                               Calculates the armor class attribute for a character.
#     0.504  GET_AC                                    Calculates the total armor class for a character based
#     0.499  GET_ATTR_WIS
#     0.498  GET_MAX_STAM                              Calculates the maximum stamina for a character.
#     0.493  get_max_stat                              Retrieves the maximum allowable stat value for a charac
#     0.486  GET_MAX_HIT                               Calculates the maximum hit points for a character.
#     0.486  GET_MAX_MANA                              Calculates the maximum mana for a character.
#     0.485  GET_ATTR_AGE
#     0.485  GET_ATTR
#     0.483  GET_ATTR_MOD
#     0.480  get_unspelled_ac                          Calculates the unmodified armor class (AC) of a charact
#     0.478  GET_DEFENSE_MOD
#     0.477  GET_ATTR_INT
#     0.477  get_unspelled_damroll                     Calculates the unspelled damage roll of a character.
#     0.476  can_carry_w                               Calculates the maximum weight a character can carry.
#     0.471  can_carry_n                               Calculates the maximum number of items a character can
#     0.469  stam_gain                                 Calculates the stamina gain for a character based on va
#     0.467  get_unspelled_hitroll                     Calculates a character's hitroll excluding spell effect
#     0.467  hit_gain                                  Calculates the hit point regeneration gain for a charac
#     0.465  GET_ATTR_SEX
#     0.465  GET_ATTR_CON
#     0.458  get_max_train                             Calculates the maximum trainable value for a given char
#     0.456  GET_ATTR_STR
#     0.453  GET_ATTR_SAVES
#     0.453  get_carry_weight                          Calculates the total carrying weight of a character.
#     0.451  stat_to_attr                              Converts a stat identifier to its corresponding attribu
#     0.442  get_play_seconds                          Calculates the total play time in seconds for a charact
#     0.442  apply_ac                                  Calculates the armor class contribution of an object ba
#     0.440  mana_gain                                 Calculates the mana gain for a character based on vario
#     0.439  GET_ATTR_DEX
#     0.436  get_age                                   Calculates the age of a character in MUD years.
#     0.428  get_play_hours                            Calculates the total play hours for a character.
#     0.427  ATTR_BASE
#     0.420  GET_RANK
#     0.415  get_locker_weight                         Calculates the total weight of items in a character's l
#     0.411  get_carry_number                          Calculates the total number of objects a character is c
#     0.406  print_defense_modifiers                   Generates a string describing a character's defense mod
#     0.403  IS_OBJ_STAT
#     0.399  deduct_stamina                            Deducts stamina from a character for using a specified
#     0.384  WEIGHT_MULT
#     0.362  level_save                                Determines if a saving throw is successful based on lev
#     0.314  set_title                                 Sets the title of a character.
#
# ================================================================================
# [projection/output] — 56 members, avg cohesion 0.383
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.510  stc                                       Sends a string to a character's output buffer with opti
#     0.484  set_color                                 Sets the text color for a character's output.
# ...
#     0.382  cJSON_CreateString                        Creates a cJSON string item from a C-style string.
#     0.377  >::pool_allocated                         Provides access to a static counter of allocated resour
#     0.369  >::delete_garbage                         Removes and deletes garbage objects from a container.
#     0.361  cJSON_CreateIntArray                      Creates a cJSON array from an array of integers.
#     0.350  CACHE_SIZE
#     0.342  Garbage::is_garbage                       Checks if the object is marked as garbage.
#     0.311  GET_CACHE
#     0.286  ensure                                    Ensures the printbuffer has enough space for additional
#
# ================================================================================
# [utility/imaging] — 4 members, avg cohesion 0.527
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.595  util::Image::width                        Retrieves the width of the object.
#     0.592  util::Image::height                       Retrieves the height value.
#     0.501  util::Image::value                        Retrieves the value of a specific color channel at a gi
#     0.420  util::Image::load                         Loads an image from a file in PNG format.
#
# ================================================================================
# [utility/text_editing] — 23 members, avg cohesion 0.571
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.651  edit_goto                                 Sets the current editing line for a character if the li
#     0.637  edit_goto1                                Sets the current editing line for a character.
#     0.623  edit_change                               Modifies a specific line in a character's edit buffer b
#     0.620  edit_insert                               Inserts a string into the current editing buffer at a s
#     0.619  edit_list                                 Formats and displays a specified range of lines from an
#     0.608  edit_status                               Displays the current editing status to a character.
#     0.604  check_line                                Checks if a given line number is within the valid range
#     0.598  edit_list1                                Formats and displays a range of lines from an edit buff
#     0.591  edit_split                                Splits the current editing line at a specified token.
#     0.587  edit_desc                                 Initializes the editing process for a character's descr
#     0.587  list_window                               Displays a window of lines around the current edit line
#     0.586  edit_done                                 Finalizes the editing process for a character.
#     0.582  edit_undo                                 Reverts the most recent change made during character ed
#     0.578  edit_note                                 Initializes the note editing process for a character.
#     0.576  edit_delete                               Deletes a range of lines from the current edit string.
#     0.564  check_range                               Checks and adjusts the range of line numbers for editin
#     0.564  edit_cancel                               Cancels the current editing session for a character.
#     0.560  edit_wrap                                 Wraps text in the editing buffer to fit within a specif
#     0.542  edit_help                                 Initiates the editing of a help entry for a character.
#     0.541  find_line                                 Finds the starting position of a specified line number
#     0.513  count_lines                               Counts the number of lines in the current editing strin
#     0.461  backup                                    Creates a backup of the current edit string.
#     0.352  is_blank_line                             Checks if a given line is blank.
#
# ================================================================================
# [domain/notes] — 10 members, avg cohesion 0.585
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.658  parse_note                                Handles various note-related commands for a character.
#     0.636  note_attach                               Attaches a new note to a character if none exists.
#     0.623  notify_note_post                          Notifies characters of a new note post based on their a
#     0.622  hide_note                                 Determines if a note should be hidden from a character.
#     0.601  is_note_to                                Determines if a note is addressed to a specific charact
#     0.596  note_remove                               Removes a note or a recipient from a note for a charact
#     0.576  append_note                               Appends a note to the appropriate list and writes it to
#     0.566  update_read                               Updates the character's last read timestamp for a speci
#     0.496  count_spool                               Counts the number of visible messages for a character i
#     0.482  save_notes                                Saves notes of a specified type to a corresponding file
#
# ================================================================================
# [utility/arg_parsing] — 8 members, avg cohesion 0.469
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.539  one_argument                              Extracts the first argument from a String and returns t
#     0.511  number_argument                           Extracts a numeric prefix from a String and returns the
#     0.497  mult_argument                             Parses a String to extract a number and a substring aft
#     0.482  String::has_words                         Determines if all words in a given wordlist are present
#     0.467  entity_argument                           Parses an entity type from a string argument and modifi
#     0.466  one_keyword                               Extracts a single keyword from a string of keywords.
#     0.453  String::has_exact_words                   Checks if all words in the given wordlist are present i
#     0.341  help_char_search                          Searches for help entries matching a keyword and sends
#
# ================================================================================
# [infrastructure/runtime] — 9 members, avg cohesion 0.415
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.529  char_update                               Updates the state of all characters, including NPCs and
#     0.472  World::update                             Updates the world state by processing areas and cleanin
#     0.458  GameTime::update                          Updates the game time and notifies characters of time c
#     0.452  obj_update                                Updates the state of all objects in the game world.
#     0.443  Weather::update                           Updates the weather conditions and notifies characters
#     0.402  World::add_char                           Adds a Character object to the world's character list.
#     0.375  interpret                                 Main command interpreter for processing player and NPC
#     0.341  close_socket                              Closes a network connection and handles associated char
#     0.262  check_disabled                            Checks if a given command is disabled.
#
# ================================================================================
# [policy/entity_lookup] — 34 members, avg cohesion 0.549
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.648  get_char_world                            Finds a character in the game world based on search cri
#     0.642  get_obj_here                              Finds an object in the room or in the character's posse
#     0.636  get_char_here                             Finds a character in the same room as the specified cha
#     0.633  get_mob_world                             Finds a mobile (NPC) character in the world based on se
#     0.630  get_mob_here                              Finds a mobile (NPC) in the same room as the specified
#     0.627  get_obj_world                             Finds an object in the game world accessible to a chara
#     0.627  get_obj_list                              Finds an object in a list that a character can see and
#     0.624  get_char_area                             Finds a character in the same area as the specified cha
#     0.617  get_player_world                          Finds a player character in the game world based on a g
#     0.614  get_obj_carry                             Finds an object in a character's inventory based on a g
#     0.609  get_char_room                             Searches for a character in a specified room based on v
#     0.592  get_obj_wear                              Finds an object worn by the player based on a given arg
#     0.592  find_location                             Finds and returns the Room associated with a given loca
#     0.564  get_warp_crystal                          Searches for an exact match of a warp crystal by its de
#     0.564  fsearch_char                              Searches for characters or NPCs with specific flags and
#     0.561  get_obj_keeper                            Retrieve an object from a shopkeeper's inventory based
#     0.559  fsearch_mobile                            Searches for NPCs in the game world that match specifie
#     0.546  fsearch_obj                               Searches for objects based on specified flags and outpu
#     0.538  fsearch_player                            Searches for players with specific flags set and output
#     0.531  fsearch_room                              Searches for rooms visible to a character that match sp
#     0.526  get_eq_char                               Retrieves the object worn by a character at a specified
#     0.514  random_prototype                          Selects a random object prototype VNUM based on a keywo
#     0.501  get_extra_descr                           Searches for an ExtraDescr with a matching keyword.
#     0.495  has_key                                   Checks if a character possesses a specific key.
#     0.490  weapon_lookup                             Finds the index of a weapon by its name.
#     0.489  name_expand                               Expands a character's name to uniquely identify them wi
#     0.488  liq_lookup                                Finds the index of a liquid whose name matches the give
#     0.487  race_lookup                               Finds the index of a race by its name.
#     0.484  quest_where                               Provides information about the location of a specified
#     0.477  attack_lookup                             Finds the index of an attack by its name.
#     0.452  Area::get_obj_prototype                   Retrieves the object prototype associated with a given
#     0.444  help                                      Processes a help request by querying the database for h
#     0.428  get_weapon_type                           Determines the weapon type based on the given name.
#     0.428  World::get_obj_prototype                  Retrieves the object prototype for a given virtual numb
#
# ================================================================================
# [domain/world_structure] — 37 members, avg cohesion 0.405
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.498  Room::guild                               Retrieves the guild value from the room's prototype.
#     0.487  RoomID::get_vnum                          Retrieves the virtual number (vnum) of the RoomID.
#     0.484  RoomID::get_number                        Retrieves the room number associated with the RoomID.
#     0.479  Room::area                                Retrieves the area associated with the room.
#     0.476  Room::sector_type                         Retrieves the sector type of the room.
#     0.473  Room::heal_rate                           Retrieves the healing rate of the room.
#     0.467  Room::mana_rate                           Retrieves the mana regeneration rate of the room.
#     0.458  Room::name                                Retrieves the name of the room.
#     0.447  World::get_room                           Retrieves a Room object based on a given Location.
#     0.447  RoomID::to_int                            Serializes the RoomID into an integer representation.
#     0.439  RoomID::is_valid                          Checks if the RoomID has been initialized correctly.
#     0.438  Room::owner                               Retrieves the owner of the room.
#     0.435  Location::to_int                          Serializes the object into an integer representation.
#     0.434  Vnum::value                               Retrieves the current value stored in the object.
#     0.433  World::get_area                           Retrieves the area associated with a given virtual numb
#     0.427  Room::is_on_map                           Determines if the room is located on a valid map coordi
#     0.426  worldmap::Worldmap::get_sector            Retrieves the sector type at a given coordinate.
#     0.424  Area::get_mob_prototype                   Retrieves a mobile prototype by its virtual number.
#     0.422  worldmap::Worldmap::height                Retrieves the height value.
#     0.416  QuestArea::area                           Retrieves the area associated with the QuestArea.
#     0.413  worldmap::Worldmap::width                 Retrieves the width value.
#     0.410  World::get_mob_prototype                  Retrieves a mobile prototype by its virtual number.
#     0.407  Area::num_players                         Returns the number of players.
#     0.402  Location::is_valid                        Checks if either the coordinate or the room ID is valid
#     0.390  worldmap::Coordinate::is_valid            Checks if the object is in a valid state.
#     0.386  Exit::key                                 Retrieves the key associated with the Exit object.
#     0.380  worldmap::Coordinate::to_int              Serializes the coordinate to an integer representation.
#     0.359  generate_skillquest_room                  Selects and returns a suitable room for a skill quest b
#     0.354  >::get                                    Retrieves the data associated with a given coordinate i
#     0.351  Game::world                               Provides access to the singleton instance of the World
#     0.332  GameTime::month_name                      Retrieves the name of the current month in the game's c
#     0.325  >::get_child_index                        Calculates the child index for a given coordinate.
#     0.321  GameTime::day_name                        Retrieves the name of the current day in the game.
#     0.316  Area::add_char                            Adds a character to the area, updating counts for playe
#     0.294  sector_lookup                             Retrieves the name of a sector based on its type.
#     0.285  create_mobile                             Creates and initializes a mobile character instance fro
#     0.267  clone_mobile                              Clones a non-player character (NPC) mobile, excluding i

# %% [markdown]
# ## Step 9: t-SNE — global embedding landscape
#
# Project all callee embeddings into 2D via t-SNE, coloured by locked group.
# This gives a visual overview of cluster separation and overlap.

# %%
# ── Prepare data for t-SNE ────────────────────────────────────────────
# Collect all locked callees with embeddings
tsne_nids = []
tsne_groups = []
tsne_types = []
tsne_names = []

for g, embs in group_embeddings.items():
    for nid, vec in embs.items():
        tsne_nids.append(nid)
        tsne_groups.append(g)
        tsne_types.append(GROUP_TYPE[g])
        tsne_names.append(callee_info.get(nid, {}).get("name", "?"))

tsne_matrix = np.stack([callee_embeddings[nid] for nid in tsne_nids])
print(f"t-SNE input: {tsne_matrix.shape[0]} vectors, {tsne_matrix.shape[1]}d")

# ── Run t-SNE ────────────────────────────────────────────────────────
tsne = TSNE(n_components=2, perplexity=30, random_state=42, init="pca", learning_rate="auto")
tsne_2d = tsne.fit_transform(tsne_matrix)
print(f"t-SNE complete: {tsne_2d.shape}")

# ── Assign colours per group ─────────────────────────────────────────
unique_groups = sorted(set(tsne_groups))
cmap = plt.colormaps.get_cmap("tab20").resampled(len(unique_groups))
group_color_map = {g: cmap(i) for i, g in enumerate(unique_groups)}

# ── Global scatter plot ──────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(16, 12))
for g in unique_groups:
    idx = [i for i, gname in enumerate(tsne_groups) if gname == g]
    ax.scatter(tsne_2d[idx, 0], tsne_2d[idx, 1],
               c=[group_color_map[g]], label=g, s=12, alpha=0.7)

ax.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=7, ncol=2, markerscale=2)
ax.set_title("t-SNE: all locked callees coloured by capability group")
ax.set_xlabel("t-SNE 1")
ax.set_ylabel("t-SNE 2")
plt.tight_layout()
plt.show()
# Out:
# t-SNE input: 837 vectors, 4096d
# t-SNE complete: (837, 2)

# %% [markdown]
# ## Step 10: t-SNE — per-group detail plots
#
# Highlight one group at a time against the greyed-out background of all other
# functions.  Useful for spotting members that land far from the group cluster.

# %%
# ── Per-group t-SNE detail plots ──────────────────────────────────────
# Show groups with at least MIN_MEMBERS members
MIN_MEMBERS = 5
groups_to_plot = [g for g in unique_groups if sum(1 for gn in tsne_groups if gn == g) >= MIN_MEMBERS]

n_plots = len(groups_to_plot)
ncols = 4
nrows = (n_plots + ncols - 1) // ncols
fig, axes = plt.subplots(nrows, ncols, figsize=(20, 5 * nrows))
axes = axes.flatten() if n_plots > 1 else [axes]

for idx, g in enumerate(groups_to_plot):
    ax = axes[idx]
    # Background: all other points in grey
    other_idx = [i for i, gn in enumerate(tsne_groups) if gn != g]
    ax.scatter(tsne_2d[other_idx, 0], tsne_2d[other_idx, 1],
               c="lightgrey", s=4, alpha=0.3)
    # Foreground: this group's points
    group_idx = [i for i, gn in enumerate(tsne_groups) if gn == g]
    ax.scatter(tsne_2d[group_idx, 0], tsne_2d[group_idx, 1],
               c=[group_color_map[g]], s=20, alpha=0.9, edgecolors="black", linewidths=0.3)

    # Label outlier members (those from step 7)
    outlier_nids_for_g = {o["node_id"] for o in outliers if o["current_subsystem"] == g}
    for i in group_idx:
        if tsne_nids[i] in outlier_nids_for_g:
            ax.annotate(tsne_names[i], (tsne_2d[i, 0], tsne_2d[i, 1]),
                       fontsize=5, alpha=0.8, color="red")

    ax.set_title(f"{g} ({len(group_idx)})", fontsize=9)
    ax.set_xticks([])
    ax.set_yticks([])

# Hide unused subplots
for idx in range(n_plots, len(axes)):
    axes[idx].set_visible(False)

fig.suptitle("Per-group t-SNE (outliers labelled in red)", fontsize=13, y=1.01)
plt.tight_layout()
plt.show()

# %%
# ── Summary statistics ────────────────────────────────────────────────
total_locked_matched = sum(len(nids) for nids in group_members.values())
total_with_emb = sum(len(e) for e in group_embeddings.values())

# Per-group avg cohesion
cohesions = {}
for g in CAPABILITY_DEFS:
    if g in sim_matrices:
        mat = sim_matrices[g]["matrix"]
        n = mat.shape[0]
        if n >= 2:
            mask = ~np.eye(n, dtype=bool)
            cohesions[g] = np.mean(mat[mask])

overall_cohesion = np.mean(list(cohesions.values())) if cohesions else 0

print("=" * 60)
print("SUMMARY")
print("=" * 60)
print(f"Groups: {len(CAPABILITY_DEFS)}")
print(f"Locked functions: {total_locked}")
print(f"Matched to callee pool: {total_locked_matched}")
print(f"With embeddings: {total_with_emb}")
print(f"Overall mean cohesion: {overall_cohesion:.3f}")
print(f"Outliers (< {OUTLIER_THRESHOLD}): {len(outliers)}")
print(f"Regroup suggestions: {len(suggestions)}")

print(f"\nGroups by cohesion:")
for g, c in sorted(cohesions.items(), key=lambda x: x[1]):
    n = len(group_embeddings.get(g, {}))
    print(f"  {c:.3f}  {g:25s} ({n:3d} members)  [{GROUP_TYPE[g]}]")
# Out:
# ============================================================
# SUMMARY
# ============================================================
# Groups: 30
# Locked functions: 851
# Matched to callee pool: 851
# With embeddings: 837
# Overall mean cohesion: 0.483
# Outliers (< 0.25): 6
# Regroup suggestions: 4
#
# Groups by cohesion:
#   0.331  persistence               ( 87 members)  [infrastructure]
#   0.382  memory                    ( 17 members)  [utility]
#   0.383  output                    ( 56 members)  [projection]
#   0.392  admin                     ( 10 members)  [infrastructure]
#   0.405  world_structure           ( 37 members)  [domain]
#   0.415  runtime                   (  9 members)  [infrastructure]
#   0.422  economy                   (  9 members)  [domain]
#   0.426  movement                  ( 34 members)  [domain]
#   0.427  display                   ( 26 members)  [projection]
#   0.436  state_rules               ( 54 members)  [policy]
#   0.437  social                    ( 10 members)  [domain]
#   0.441  string_ops                ( 41 members)  [utility]
#   0.448  objects                   ( 43 members)  [domain]
#   0.456  numerics                  ( 13 members)  [utility]
#   0.457  attributes                ( 45 members)  [policy]
#   0.469  arg_parsing               (  8 members)  [utility]
#   0.492  combat                    ( 25 members)  [domain]
#   0.496  skills_progression        ( 31 members)  [domain]
#   0.519  clans                     ( 30 members)  [domain]
#   0.527  imaging                   (  4 members)  [utility]
#   0.528  affects                   ( 88 members)  [domain]
#   0.543  npc_behavior              ( 21 members)  [domain]
#   0.549  entity_lookup             ( 34 members)  [policy]
#   0.550  magic                     (  6 members)  [domain]
#   0.571  text_editing              ( 23 members)  [utility]
#   0.579  flags                     ( 34 members)  [utility]
#   0.581  quests                    ( 16 members)  [domain]
#   0.585  notes                     ( 10 members)  [domain]
#   0.620  pvp                       (  6 members)  [domain]
#   0.632  visibility_rules          ( 10 members)  [policy]

# %%
# ── Export locked classifications with cohesion metadata ──────────────
def _f(v):
    """Convert numpy scalars to Python float for JSON serialization."""
    return float(v) if hasattr(v, "item") else v

export = {
    "metadata": {
        "total_callees": len(all_callee_nodes),
        "locked": total_locked,
        "matched": total_locked_matched,
        "with_embedding": total_with_emb,
        "groups": len(CAPABILITY_DEFS),
        "overall_cohesion": round(float(overall_cohesion), 4),
        "outlier_threshold": OUTLIER_THRESHOLD,
        "n_outliers": len(outliers),
        "n_regroup_suggestions": len(suggestions),
    },
    "group_cohesion": {
        g: round(float(c), 4) for g, c in sorted(cohesions.items(), key=lambda x: x[1])
    },
    "outliers": [
        {
            "name": o["name"],
            "group": o["current_subsystem"],
            "avg_sim": round(float(o["average_similarity"]), 4),
        }
        for o in outliers
    ],
    "regroup_suggestions": [
        {
            "name": s["name"],
            "from": s["current_subsystem"],
            "to": s["suggested_subsystem"],
            "delta": round(float(s["suggested_similarity"] - s["current_similarity"]), 4),
            "confidence": round(float(s["confidence"]), 4),
        }
        for s in suggestions
    ],
}

out_path = HERE / "capability_classifications.json"
with open(out_path, "w") as f:
    json.dump(export, f, indent=2)
print(f"Exported to {out_path.name}")
# Out:
# Exported to capability_classifications.json
