# %% [markdown]
# # Capability Group Analysis
#
# Analyzes the locked capability assignments (from `capability_defs.json`) for the
# ~852 callee functions reachable from command/spell/spec entry points.
#
# **Focus:**
# 1. Load locked group assignments and resolve embeddings
# 2. **Intra-group cohesion** — how tightly clustered is each group?
# 3. **Inter-group similarity** — which groups overlap? Which functions fit better elsewhere?
# 4. **t-SNE visualisation** — per-group and global embedding landscape
#
# Uses `EmbeddingRefiner` from the clustering pipeline for similarity matrices,
# outlier detection, and regroup suggestions.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# ── Setup & imports ──────────────────────────────────────────────────
from __future__ import annotations

import json
import pickle
from collections import Counter, defaultdict
from pathlib import Path

import numpy as np
import networkx as nx
from fastembed import TextEmbedding
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import matplotlib.cm as cm

HERE = Path(".").resolve()

import legacy_common.doc_db as ddb
import legacy_common.doxygen_graph as dg
import legacy_common.doxygen_parse as dp
from legacy_common import ARTIFACTS_DIR
from legacy_common.entity_ids import compute_entity_id
from legacy_common.embedding_refiner import EmbeddingRefiner
from legacy_common.subsystem_utils import Subsystem

# ── Lazy fastembed model (for ad-hoc text embedding) ─────────────────
_fastembed_model: TextEmbedding | None = None

def embed_text(text: str) -> np.ndarray:
    """Embed a single text using the local ONNX model."""
    global _fastembed_model
    if _fastembed_model is None:
        _fastembed_model = TextEmbedding(model_name="BAAI/bge-base-en-v1.5")
    return np.array(list(_fastembed_model.embed([text])), dtype=np.float32)[0]

# ── Load artifacts ───────────────────────────────────────────────────
graph = dg.load_graph(ARTIFACTS_DIR / "code_graph.gml")
entity_db = dp.load_db(ARTIFACTS_DIR / "code_graph.json")
doc_db = ddb.DocumentDB(docs_dir=ARTIFACTS_DIR / "generated_docs")

with open(ARTIFACTS_DIR / "capability_defs.json") as f:
    CAPABILITY_DEFS: dict[str, dict] = json.load(f)

# Build quick lookups
GROUP_TYPE = {name: d["type"] for name, d in CAPABILITY_DEFS.items()}
TYPE_ORDER = ["utility", "infrastructure", "policy", "projection", "domain"]
TYPE_COLORS = {
    "utility":        "#7f7f7f",
    "infrastructure": "#8c564b",
    "policy":         "#d62728",
    "projection":     "#ff7f0e",
    "domain":         "#1f77b4",
}

# ── Initialise EmbeddingRefiner (for similarity analysis — no embedding endpoint needed) ──
refiner = EmbeddingRefiner(entity_db, graph, doc_db)

print(f"Graph: {graph.number_of_nodes()} nodes, {graph.number_of_edges()} edges")
print(f"Entity DB: {len(entity_db.entities)} entities")
print(f"Doc DB: {len(doc_db)} documents")
type_summary = ", ".join(
    f"{t}={sum(1 for v in CAPABILITY_DEFS.values() if v['type'] == t)}"
    for t in TYPE_ORDER
)
print(f"Capability groups: {len(CAPABILITY_DEFS)} ({type_summary})")
print(f"Embedding model: BAAI/bge-base-en-v1.5 (local ONNX via fastembed)")

# %matplotlib inline
plt.rcParams.update({"figure.dpi": 120, "figure.figsize": (12, 8)})
# Out:
# 2026-03-18 17:51:15.943 | INFO     | legacy_common.doxygen_graph:load_graph:616 - Graph loaded from /Users/QTE2333/repos/legacy-projects/artifacts/code_graph.gml, nodes: 14507, edges: 44544
# Graph: 14507 nodes, 44544 edges
# Entity DB: 5305 entities
# Doc DB: 475 documents
# Capability groups: 30 (utility=7, infrastructure=3, policy=4, projection=2, domain=14)
# Embedding model: BAAI/bge-base-en-v1.5 (local ONNX via fastembed)

# %% [markdown]
# ## Step 1: Extract transitive call trees
#
# Find all entry-point functions — `do_*` (command handlers), `spell_*` (spell
# effect implementations), and `spec_*` (NPC special functions) — then BFS along
# `calls` edges to collect every reachable function. This captures the true
# dependency footprint, including cross-group dependencies at depth ≥2.
#
# Entry points are excluded from each other's callee sets.
# We track call depth per callee for later analysis.

# %%
# ── Helpers ──────────────────────────────────────────────────────────
ENTRY_PREFIXES = ("do_", "spell_", "spec_")

def entry_point_name(sig: str) -> str:
    """Extract the short name (do_kill, spell_fireball, spec_guard) from a signature."""
    for prefix in ENTRY_PREFIXES:
        idx = sig.find(prefix)
        if idx >= 0:
            end = sig.find("(", idx)
            return sig[idx:end] if end >= 0 else sig[idx:]
    return sig

def bare_name(sig: str) -> str:
    paren = sig.find("(")
    if paren > 0:
        sig = sig[:paren]
    space = sig.rfind(" ")
    if space > 0:
        sig = sig[space + 1:]
    return sig

def is_entry_point(name: str) -> bool:
    """Check if a function name contains an entry-point prefix."""
    return any(f" {p}" in name or name.startswith(p) for p in ENTRY_PREFIXES)

def get_calls_successors(g, node_id):
    """Return set of nodes reachable via a single 'calls' edge from node_id."""
    return {v for _, v, ed in g.edges(node_id, data=True)
            if ed.get("type") == "calls"}

def transitive_callees_bfs(g, start_node, exclude_nodes):
    """BFS along 'calls' edges. Returns dict {node_id: min_depth}."""
    visited = {}
    queue = []
    for callee in get_calls_successors(g, start_node):
        if callee not in exclude_nodes and callee != start_node:
            visited[callee] = 1
            queue.append((callee, 1))
    
    while queue:
        node, depth = queue.pop(0)
        for callee in get_calls_successors(g, node):
            if callee not in visited and callee not in exclude_nodes:
                visited[callee] = depth + 1
                queue.append((callee, depth + 1))
    return visited

# ── Find entry points ────────────────────────────────────────────────
entry_points = [
    (n, d) for n, d in graph.nodes(data=True)
    if d.get("kind") == "function" and is_entry_point(d.get("name", ""))
]
entry_point_nodes = {n for n, _ in entry_points}

# Categorize
do_funcs = [(n, d) for n, d in entry_points if " do_" in d.get("name", "")]
spell_funcs = [(n, d) for n, d in entry_points if " spell_" in d.get("name", "")]
spec_funcs = [(n, d) for n, d in entry_points if " spec_" in d.get("name", "")]
print(f"Entry points: {len(entry_points)} total")
print(f"  do_*:    {len(do_funcs)} command handlers")
print(f"  spell_*: {len(spell_funcs)} spell effects")
print(f"  spec_*:  {len(spec_funcs)} NPC special functions")

# ── Collect transitive callees via BFS ───────────────────────────────
cmd_callees: dict[str, dict[str, int]] = {}  # entry_name -> {node_id: min_depth}
all_callee_nodes: set[str] = set()
callee_min_depth: dict[str, int] = {}  # global min depth across all entry points

for node_id, node_data in entry_points:
    cmd = entry_point_name(node_data.get("name", "?"))
    callees = transitive_callees_bfs(graph, node_id, entry_point_nodes)
    cmd_callees[cmd] = callees
    for nid, depth in callees.items():
        all_callee_nodes.add(nid)
        callee_min_depth[nid] = min(callee_min_depth.get(nid, 999), depth)

# ── Depth distribution ───────────────────────────────────────────────
depth_dist = Counter(callee_min_depth.values())
direct_only = {nid for nid, d in callee_min_depth.items() if d == 1}
deeper = all_callee_nodes - direct_only

print(f"\nUnique callees (transitive): {len(all_callee_nodes)}")
print(f"  Direct (depth 1): {len(direct_only)}")
print(f"  Deeper (depth ≥2): {len(deeper)}")
print(f"\nDepth distribution (min depth across all entry points):")
for d in sorted(depth_dist.keys()):
    print(f"  depth {d}: {depth_dist[d]} callees")

# Per-entry-point expansion
direct_counts = [sum(1 for d in c.values() if d == 1) for c in cmd_callees.values()]
total_counts = [len(c) for c in cmd_callees.values()]
print(f"\nPer-entry-point callee counts:")
print(f"  Direct: mean={np.mean(direct_counts):.1f}, median={np.median(direct_counts):.0f}, max={max(direct_counts)}")
print(f"  Total:  mean={np.mean(total_counts):.1f}, median={np.median(total_counts):.0f}, max={max(total_counts)}")
# Out:
# Entry points: 633 total
#   do_*:    442 command handlers
#   spell_*: 160 spell effects
#   spec_*:  31 NPC special functions
#
# Unique callees (transitive): 853
#   Direct (depth 1): 559
#   Deeper (depth ≥2): 294
#
# Depth distribution (min depth across all entry points):
#   depth 1: 559 callees
#   depth 2: 194 callees
#   depth 3: 57 callees
#   depth 4: 28 callees
#   depth 5: 12 callees
#   depth 6: 2 callees
#   depth 7: 1 callees
#
# Per-entry-point callee counts:
#   Direct: mean=8.4, median=7, max=52
#   Total:  mean=122.2, median=95, max=418

# %% [markdown]
# ## Step 2: Resolve callee metadata and documentation
#
# For each callee node, resolve:
# - bare function name (from graph node attributes)
# - minimum call depth (from transitive BFS)
# - entity ID (via `get_body_eid`)
# - doc_db document (brief, details, rationale)
# - full documentation text for embedding

# %%
# ── Resolve callee info ──────────────────────────────────────────────
callee_info: dict[str, dict] = {}

for node_id in sorted(all_callee_nodes):
    vd = graph.nodes[node_id]
    full_sig = vd.get("name", node_id)
    name = bare_name(full_sig)

    # Resolve entity, doc, and deterministic entity ID
    eid = None
    doc = None
    doc_text = None
    det_id = None
    try:
        eid = dg.get_body_eid(entity_db, node_id)
        entity = entity_db.get(eid)
        if entity:
            cid = eid.compound
            second = eid.member if eid.member else cid
            det_id = compute_entity_id(entity.kind, cid, second)
            doc = doc_db.get_doc(cid, entity.signature)
            if doc is None and cid in doc_db:
                for _sig, d in doc_db[cid].items():
                    if d.name == entity.name and d.brief:
                        doc = d
                        break
    except Exception:
        pass

    if doc:
        doc_text = doc.to_doxygen()

    callee_info[node_id] = {
        "name": name,
        "sig": full_sig,
        "min_depth": callee_min_depth.get(node_id, 999),
        "eid": str(eid) if eid else None,
        "brief": doc.brief if doc else None,
        "doc_text": doc_text,
        "det_id": det_id,
    }

documented = sum(1 for v in callee_info.values() if v["brief"])
has_text = sum(1 for v in callee_info.values() if v["doc_text"])
depth1 = sum(1 for v in callee_info.values() if v["min_depth"] == 1)
print(f"Callees: {len(callee_info)}")
print(f"  At depth 1: {depth1}")
print(f"  At depth ≥2: {len(callee_info) - depth1}")
print(f"  With doc brief: {documented}")
print(f"  With full doc text: {has_text}")
print(f"  With entity ID: {sum(1 for v in callee_info.values() if v['det_id'])}")
print(f"  Undocumented: {len(callee_info) - documented}")
# Out:
# Callees: 853
#   At depth 1: 559
#   At depth ≥2: 294
#   With doc brief: 853
#   With full doc text: 853
#   With entity ID: 853
#   Undocumented: 0

# %% [markdown]
# ## Step 3: Resolve embeddings
#
# Load the pre-computed embedding cache (keyed by deterministic entity ID).
# For callees not in cache, embed the doc text using the local fastembed model.

# %%
EMBED_CACHE_PATH = ARTIFACTS_DIR / "embed_cache_BAAI-bge-base-en-v1.5_768.pkl"

# Load cached embeddings (keyed by deterministic entity ID)
with open(EMBED_CACHE_PATH, "rb") as f:
    all_embeddings: dict[str, list[float]] = pickle.load(f)

sample_vec = next(iter(all_embeddings.values()))
sample_dim = np.asarray(sample_vec).shape[0]
print(f"Cached embeddings: {len(all_embeddings)} ({sample_dim}d)")

# ── Resolve callee embeddings ────────────────────────────────────────
callee_embeddings: dict[str, np.ndarray] = {}
missing_embedding: list[str] = []

# 1. Try cache first (keyed by deterministic entity ID)
for node_id, info in callee_info.items():
    det_id = info["det_id"]
    if det_id and det_id in all_embeddings:
        callee_embeddings[node_id] = np.asarray(all_embeddings[det_id], dtype=np.float32)
    else:
        missing_embedding.append(node_id)

print(f"Callees with cached embedding: {len(callee_embeddings)}")
print(f"Callees missing from cache: {len(missing_embedding)}")

# 2. For missing callees, embed doc text via fastembed
encoded_via_fallback = 0
still_missing = []
for nid in missing_embedding:
    doc_text = callee_info[nid].get("doc_text")
    if doc_text:
        callee_embeddings[nid] = embed_text(doc_text)
        encoded_via_fallback += 1
    else:
        still_missing.append(nid)

no_embedding = still_missing
print(f"Encoded via fastembed fallback: {encoded_via_fallback}")
print(f"Total with embedding: {len(callee_embeddings)}/{len(all_callee_nodes)}")
print(f"No embedding (undocumented): {len(no_embedding)}")

# ── Build name→node_id lookup (bare name → node_id) ─────────────────
name_to_nid: dict[str, str] = {}
for nid, info in callee_info.items():
    name_to_nid[info["name"]] = nid  # last-wins for the 1 duplicate

print(f"Bare name → node_id mappings: {len(name_to_nid)}")
# Out:
# Cached embeddings: 5305 (768d)
# Callees with cached embedding: 853
# Callees missing from cache: 0
# Encoded via fastembed fallback: 0
# Total with embedding: 853/853
# No embedding (undocumented): 0
# Bare name → node_id mappings: 852

# %% [markdown]
# ## Step 4: Load locked group assignments
#
# Read the `locked` lists from `capability_defs.json` to build definitive group
# memberships.  Functions are matched by bare name to the callee node IDs discovered
# in step 1.  Any locked names missing from the callee pool (or without embeddings)
# are reported.

# %%
# ── Build group assignments from locked lists ────────────────────────
group_members: dict[str, list[str]] = {}   # group → [node_id, ...]
group_embeddings: dict[str, dict[str, np.ndarray]] = {}  # for refiner
name_to_group: dict[str, str] = {}         # bare_name → group
unmatched_locked: list[tuple[str, str]] = []
no_emb_locked: list[tuple[str, str]] = []

for group_name, gdef in CAPABILITY_DEFS.items():
    locked_names = gdef.get("locked", [])
    nids = []
    embs = {}
    for fn_name in locked_names:
        name_to_group[fn_name] = group_name
        nid = name_to_nid.get(fn_name)
        if nid is None:
            unmatched_locked.append((fn_name, group_name))
            continue
        nids.append(nid)
        if nid in callee_embeddings:
            embs[nid] = callee_embeddings[nid]
        else:
            no_emb_locked.append((fn_name, group_name))
    group_members[group_name] = nids
    group_embeddings[group_name] = embs

total_locked = sum(len(gdef.get("locked", [])) for gdef in CAPABILITY_DEFS.values())
total_matched = sum(len(nids) for nids in group_members.values())
total_with_emb = sum(len(e) for e in group_embeddings.values())

print(f"Locked function names: {total_locked}")
print(f"Matched to callee pool: {total_matched}")
print(f"With embedding: {total_with_emb}")
print(f"Unmatched (not in callee pool): {len(unmatched_locked)}")
print(f"No embedding (undocumented): {len(no_emb_locked)}")

if unmatched_locked:
    print(f"\nUnmatched locked names:")
    for fn, g in unmatched_locked:
        print(f"  {g:25s}  {fn}")

# ── Build Subsystem objects for refiner ──────────────────────────────
subsystems: dict[str, Subsystem] = {}
for group_name in CAPABILITY_DEFS:
    nids = set(group_members.get(group_name, []))
    subsystems[group_name] = Subsystem(
        subsystem_id=group_name,
        name=group_name,
        nodes=nids,
        classification=GROUP_TYPE[group_name],
        description=CAPABILITY_DEFS[group_name]["desc"],
    )

print(f"\nGroup sizes (with embeddings):")
for t in TYPE_ORDER:
    groups = [(g, len(group_embeddings.get(g, {})))
              for g in CAPABILITY_DEFS if GROUP_TYPE[g] == t]
    for g, n in sorted(groups, key=lambda x: -x[1]):
        print(f"  [{t:14s}] {g:25s} {n:4d}")
# Out:
# Locked function names: 852
# Matched to callee pool: 852
# With embedding: 852
# Unmatched (not in callee pool): 0
# No embedding (undocumented): 0
#
# Group sizes (with embeddings):
#   [utility       ] string_ops                  40
#   [utility       ] flags                       27
#   [utility       ] text_editing                23
#   [utility       ] memory                      17
#   [utility       ] arg_parsing                 14
#   [utility       ] numerics                    12
#   [utility       ] imaging                      4
#   [infrastructure] persistence                 94
#   [infrastructure] admin                       10
#   [infrastructure] runtime                      9
#   [policy        ] state_rules                 56
#   [policy        ] attributes                  45
#   [policy        ] entity_lookup               34
#   [policy        ] visibility_rules            10
#   [projection    ] output                      57
#   [projection    ] display                     27
#   [domain        ] affects                     89
#   [domain        ] objects                     44
#   [domain        ] world_structure             36
#   [domain        ] movement                    34
#   [domain        ] skills_progression          33
#   [domain        ] clans                       30
#   [domain        ] combat                      25
#   [domain        ] npc_behavior                24
#   [domain        ] quests                      17
#   [domain        ] social                      10
#   [domain        ] notes                       10
#   [domain        ] economy                      9
#   [domain        ] magic                        6
#   [domain        ] pvp                          6

# %% [markdown]
# ## Step 5: Intra-group cohesion
#
# Compute the pairwise cosine similarity matrix within each group.
# Report average, min, and max off-diagonal similarity as cohesion metrics.
#
# The range plot below shows the full **min → max** spread of pairwise similarities
# within each group, with the mean marked.  Wide ranges indicate heterogeneous groups;
# tight ranges indicate consistent internal similarity.

# %%
# ── Intra-group similarity via refiner ────────────────────────────────
sim_matrices = refiner.calculate_similarity_matrices(group_embeddings)

cohesion_rows = []
print(f"{'Group':30s} {'Type':14s} {'N':>4s}  {'Avg':>5s}  {'Min':>5s}  {'Max':>5s}  {'Stability'}")
print("-" * 105)

for t in TYPE_ORDER:
    groups = [g for g in CAPABILITY_DEFS if GROUP_TYPE[g] == t and g in sim_matrices]
    for g in sorted(groups, key=lambda g: -len(group_embeddings.get(g, {}))):
        sm = sim_matrices[g]
        mat = sm["matrix"]
        n = mat.shape[0]
        if n < 2:
            continue
        mask = ~np.eye(n, dtype=bool)
        off_diag = mat[mask]
        avg, mn, mx = np.mean(off_diag), np.min(off_diag), np.max(off_diag)
        q25, q75 = np.percentile(off_diag, [25, 75])
        stab = CAPABILITY_DEFS[g].get("stability", "")
        cohesion_rows.append((g, t, n, avg, mn, mx, q25, q75, stab))
        print(f"  {g:28s} {t:14s} {n:4d}  {avg:.3f}  {mn:.3f}  {mx:.3f}  {stab}")

# ── Cohesion range plot ──────────────────────────────────────────────
# Sort by mean cohesion (ascending → weakest at top)
rows_sorted = sorted(cohesion_rows, key=lambda r: r[3])
names  = [r[0] for r in rows_sorted]
avgs   = [r[3] for r in rows_sorted]
mins   = [r[4] for r in rows_sorted]
maxs   = [r[5] for r in rows_sorted]
q25s   = [r[6] for r in rows_sorted]
q75s   = [r[7] for r in rows_sorted]
colors = [TYPE_COLORS[r[1]] for r in rows_sorted]

fig, ax = plt.subplots(figsize=(14, max(6, len(names) * 0.35)))
y_pos = np.arange(len(names))

# Thin line: full min→max range
for i in range(len(names)):
    ax.plot([mins[i], maxs[i]], [y_pos[i], y_pos[i]],
            color=colors[i], linewidth=1, alpha=0.5, solid_capstyle="round")

# Thick bar: IQR (25th–75th percentile)
for i in range(len(names)):
    ax.plot([q25s[i], q75s[i]], [y_pos[i], y_pos[i]],
            color=colors[i], linewidth=5, alpha=0.7, solid_capstyle="round")

# Dot: mean
ax.scatter(avgs, y_pos, color=colors, s=30, zorder=5, edgecolors="black", linewidths=0.5)

ax.set_yticks(y_pos)
ax.set_yticklabels(names, fontsize=8)
ax.set_xlabel("Pairwise cosine similarity (within group)")
ax.set_title("Group Cohesion — range of intra-group similarities\n"
             "thin line = min–max, thick bar = IQR (25th–75th pctl), dot = mean")
ax.set_xlim(-0.05, 1.05)

# Legend for type colours
from matplotlib.patches import Patch
legend_handles = [Patch(facecolor=TYPE_COLORS[t], label=t) for t in TYPE_ORDER]
ax.legend(handles=legend_handles, loc="lower right", fontsize=8)

plt.tight_layout()
plt.show()
# Out:
# Group                          Type              N    Avg    Min    Max  Stability
# ---------------------------------------------------------------------------------------------------------
#   string_ops                   utility          40  0.747  0.579  0.963  stable
#   flags                        utility          27  0.789  0.651  0.917  stable
#   text_editing                 utility          23  0.797  0.642  0.942  stable
#   memory                       utility          17  0.709  0.557  0.938  stable
#   arg_parsing                  utility          14  0.751  0.643  0.959  stable
#   numerics                     utility          12  0.737  0.573  0.888  stable
#   imaging                      utility           4  0.809  0.775  0.892  stable
#   persistence                  infrastructure   94  0.684  0.495  0.978  stable
#   admin                        infrastructure   10  0.711  0.584  0.896  stable
#   runtime                      infrastructure    9  0.699  0.595  0.841  stable
#   state_rules                  policy           56  0.707  0.548  0.932  stable
#   attributes                   policy           45  0.741  0.561  0.948  stable
#   entity_lookup                policy           34  0.762  0.616  0.974  stable
#   visibility_rules             policy           10  0.803  0.671  0.953  stable
#   output                       projection       57  0.678  0.506  0.948  stable
#   display                      projection       27  0.702  0.556  0.932  provisional
#   affects                      domain           89  0.744  0.538  0.958  stable
#   objects                      domain           44  0.714  0.538  0.934  likely_split
#   world_structure              domain           36  0.701  0.570  0.976  likely_split
#   movement                     domain           34  0.713  0.542  0.951  stable
#   skills_progression           domain           33  0.742  0.562  0.935  stable
#   clans                        domain           30  0.740  0.571  0.937  stable
#   combat                       domain           25  0.753  0.618  0.917  stable
#   npc_behavior                 domain           24  0.768  0.540  0.902  likely_split
#   quests                       domain           17  0.794  0.666  0.962  stable
#   social                       domain           10  0.710  0.507  0.924  stable
#   notes                        domain           10  0.802  0.689  0.879  stable
#   economy                      domain            9  0.678  0.550  0.887  stable
#   magic                        domain            6  0.755  0.696  0.830  stable
#   pvp                          domain            6  0.802  0.725  0.874  stable

# %% [markdown]
# ## Step 6: Inter-group similarity matrix
#
# Compute the mean centroid-to-centroid similarity between all group pairs.
# High inter-group similarity suggests overlapping definitions or candidates for merging.

# %%
# ── Compute group centroids ───────────────────────────────────────────
group_centroids: dict[str, np.ndarray] = {}
for g, embs in group_embeddings.items():
    if embs:
        group_centroids[g] = np.mean(np.stack(list(embs.values())), axis=0)

ordered_groups = [g for t in TYPE_ORDER for g in CAPABILITY_DEFS if GROUP_TYPE[g] == t and g in group_centroids]
centroid_matrix = np.stack([group_centroids[g] for g in ordered_groups])

# ── Inter-group cosine similarity ────────────────────────────────────
inter_sim = cosine_similarity(centroid_matrix, centroid_matrix)

fig, ax = plt.subplots(figsize=(14, 12))
im = ax.imshow(inter_sim, cmap="RdYlGn", vmin=0, vmax=1)
ax.set_xticks(range(len(ordered_groups)))
ax.set_yticks(range(len(ordered_groups)))
ax.set_xticklabels(ordered_groups, rotation=90, fontsize=8)
ax.set_yticklabels(ordered_groups, fontsize=8)
ax.set_title("Inter-group centroid similarity")
fig.colorbar(im, ax=ax, shrink=0.7)

# Annotate cells with values
for i in range(len(ordered_groups)):
    for j in range(len(ordered_groups)):
        if i != j and inter_sim[i, j] > 0.55:
            ax.text(j, i, f"{inter_sim[i,j]:.2f}", ha="center", va="center", fontsize=6, color="black")

plt.tight_layout()
plt.show()

# ── Report high inter-group similarities ─────────────────────────────
print("\nTop inter-group similarities (>0.55):")
pairs = []
for i, g1 in enumerate(ordered_groups):
    for j, g2 in enumerate(ordered_groups):
        if i < j and inter_sim[i, j] > 0.55:
            pairs.append((g1, g2, inter_sim[i, j]))
pairs.sort(key=lambda x: -x[2])
for g1, g2, s in pairs:
    print(f"  {s:.3f}  {g1:25s} ↔ {g2}")
# Out:
# Top inter-group similarities (>0.55):
#   0.962  output                    ↔ display
#   0.947  admin                     ↔ output
#   0.945  memory                    ↔ persistence
#   0.938  display                   ↔ movement
#   0.938  string_ops                ↔ arg_parsing
#   0.931  entity_lookup             ↔ display
#   0.931  persistence               ↔ output
#   0.930  combat                    ↔ skills_progression
#   0.928  entity_lookup             ↔ movement
#   0.926  attributes                ↔ skills_progression
#   0.926  combat                    ↔ magic
#   0.924  admin                     ↔ display
#   0.924  state_rules               ↔ movement
#   0.923  entity_lookup             ↔ objects
#   0.921  state_rules               ↔ attributes
#   0.920  magic                     ↔ skills_progression
#   0.920  runtime                   ↔ movement
#   0.917  state_rules               ↔ combat
#   0.917  persistence               ↔ display
#   0.915  string_ops                ↔ persistence
#   0.915  state_rules               ↔ skills_progression
#   0.910  string_ops                ↔ output
#   0.910  entity_lookup             ↔ output
#   0.909  persistence               ↔ objects
#   0.909  arg_parsing               ↔ output
#   0.908  runtime                   ↔ display
#   0.908  output                    ↔ movement
#   0.907  movement                  ↔ objects
#   0.907  display                   ↔ skills_progression
#   0.905  entity_lookup             ↔ world_structure
#   0.904  runtime                   ↔ affects
#   0.903  display                   ↔ world_structure
#   0.903  display                   ↔ objects
#   0.902  runtime                   ↔ output
#   0.900  runtime                   ↔ objects
#   0.900  runtime                   ↔ state_rules
#   0.900  attributes                ↔ combat
#   0.900  persistence               ↔ admin
#   0.899  persistence               ↔ entity_lookup
#   0.899  movement                  ↔ skills_progression
#   0.899  arg_parsing               ↔ persistence
#   0.898  state_rules               ↔ visibility_rules
#   0.898  objects                   ↔ economy
#   0.898  admin                     ↔ runtime
#   0.896  state_rules               ↔ display
#   0.896  movement                  ↔ world_structure
#   0.895  text_editing              ↔ output
#   0.895  combat                    ↔ movement
#   0.895  runtime                   ↔ skills_progression
#   0.895  state_rules               ↔ npc_behavior
#   0.894  attributes                ↔ objects
#   0.894  state_rules               ↔ objects
#   0.893  skills_progression        ↔ quests
#   0.893  entity_lookup             ↔ skills_progression
#   0.893  runtime                   ↔ combat
#   0.893  state_rules               ↔ quests
#   0.892  affects                   ↔ movement
#   0.891  state_rules               ↔ entity_lookup
#   0.891  affects                   ↔ objects
#   0.890  arg_parsing               ↔ admin
#   0.890  state_rules               ↔ output
#   0.890  attributes                ↔ display
#   0.890  arg_parsing               ↔ entity_lookup
#   0.890  output                    ↔ skills_progression
#   0.889  string_ops                ↔ display
#   0.888  movement                  ↔ quests
#   0.888  skills_progression        ↔ objects
#   0.888  output                    ↔ social
#   0.887  persistence               ↔ movement
#   0.887  persistence               ↔ runtime
#   0.886  display                   ↔ affects
#   0.886  runtime                   ↔ social
#   0.886  visibility_rules          ↔ movement
#   0.886  persistence               ↔ world_structure
#   0.886  runtime                   ↔ npc_behavior
#   0.885  movement                  ↔ social
#   0.884  string_ops                ↔ admin
#   0.884  magic                     ↔ affects
#   0.884  state_rules               ↔ economy
#   0.883  admin                     ↔ movement
#   0.882  attributes                ↔ entity_lookup
#   0.882  attributes                ↔ movement
#   0.881  arg_parsing               ↔ display
#   0.881  state_rules               ↔ affects
#   0.881  output                    ↔ npc_behavior
#   0.881  runtime                   ↔ entity_lookup
#   0.880  memory                    ↔ objects
#   0.880  memory                    ↔ world_structure
#   0.880  entity_lookup             ↔ npc_behavior
#   0.879  output                    ↔ objects
#   0.878  movement                  ↔ npc_behavior
#   0.878  combat                    ↔ quests
#   0.878  display                   ↔ combat
#   0.878  state_rules               ↔ magic
#   0.878  objects                   ↔ world_structure
#   0.878  state_rules               ↔ social
#   0.878  attributes                ↔ economy
#   0.878  objects                   ↔ npc_behavior
#   0.878  runtime                   ↔ magic
#   0.877  display                   ↔ social
#   0.877  entity_lookup             ↔ quests
#   0.876  string_ops                ↔ memory
#   0.876  entity_lookup             ↔ social
#   0.875  string_ops                ↔ entity_lookup
#   0.874  text_editing              ↔ admin
#   0.874  display                   ↔ magic
#   0.874  combat                    ↔ affects
#   0.873  attributes                ↔ output
#   0.873  flags                     ↔ arg_parsing
#   0.873  output                    ↔ affects
#   0.873  persistence               ↔ social
#   0.872  output                    ↔ world_structure
#   0.872  text_editing              ↔ display
#   0.871  runtime                   ↔ attributes
#   0.871  display                   ↔ npc_behavior
#   0.870  persistence               ↔ affects
#   0.870  admin                     ↔ entity_lookup
#   0.870  combat                    ↔ npc_behavior
#   0.870  display                   ↔ quests
#   0.870  entity_lookup             ↔ affects
#   0.870  runtime                   ↔ quests
#   0.869  persistence               ↔ skills_progression
#   0.869  attributes                ↔ magic
#   0.869  affects                   ↔ skills_progression
#   0.869  admin                     ↔ social
#   0.868  persistence               ↔ state_rules
#   0.868  persistence               ↔ npc_behavior
#   0.867  admin                     ↔ skills_progression
#   0.867  string_ops                ↔ world_structure
#   0.867  combat                    ↔ objects
#   0.867  magic                     ↔ movement
#   0.866  admin                     ↔ npc_behavior
#   0.866  admin                     ↔ state_rules
#   0.865  movement                  ↔ pvp
#   0.865  entity_lookup             ↔ economy
#   0.864  magic                     ↔ objects
#   0.864  attributes                ↔ affects
#   0.863  imaging                   ↔ world_structure
#   0.863  output                    ↔ magic
#   0.862  output                    ↔ notes
#   0.862  affects                   ↔ social
#   0.862  admin                     ↔ affects
#   0.862  social                    ↔ clans
#   0.861  movement                  ↔ economy
#   0.861  string_ops                ↔ flags
#   0.861  text_editing              ↔ movement
#   0.860  memory                    ↔ output
#   0.860  admin                     ↔ objects
#   0.860  objects                   ↔ quests
#   0.860  skills_progression        ↔ economy
#   0.859  persistence               ↔ attributes
#   0.859  visibility_rules          ↔ display
#   0.859  affects                   ↔ npc_behavior
#   0.859  skills_progression        ↔ npc_behavior
#   0.859  flags                     ↔ output
#   0.859  quests                    ↔ npc_behavior
#   0.858  visibility_rules          ↔ entity_lookup
#   0.858  display                   ↔ economy
#   0.857  state_rules               ↔ clans
#   0.857  flags                     ↔ persistence
#   0.857  skills_progression        ↔ social
#   0.856  text_editing              ↔ persistence
#   0.856  persistence               ↔ economy
#   0.856  objects                   ↔ social
#   0.855  attributes                ↔ quests
#   0.855  display                   ↔ notes
#   0.854  entity_lookup             ↔ combat
#   0.854  runtime                   ↔ economy
#   0.854  arg_parsing               ↔ world_structure
#   0.854  social                    ↔ npc_behavior
#   0.853  output                    ↔ combat
#   0.853  magic                     ↔ npc_behavior
#   0.853  flags                     ↔ world_structure
#   0.852  text_editing              ↔ runtime
#   0.851  memory                    ↔ display
#   0.851  economy                   ↔ world_structure
#   0.851  output                    ↔ quests
#   0.849  movement                  ↔ clans
#   0.848  persistence               ↔ notes
#   0.848  arg_parsing               ↔ movement
#   0.848  string_ops                ↔ text_editing
#   0.848  memory                    ↔ affects
#   0.848  runtime                   ↔ world_structure
#   0.848  entity_lookup             ↔ magic
#   0.848  admin                     ↔ notes
#   0.848  text_editing              ↔ arg_parsing
#   0.847  flags                     ↔ admin
#   0.847  flags                     ↔ display
#   0.846  affects                   ↔ economy
#   0.846  objects                   ↔ clans
#   0.846  admin                     ↔ attributes
#   0.846  memory                    ↔ runtime
#   0.846  attributes                ↔ world_structure
#   0.846  skills_progression        ↔ world_structure
#   0.846  admin                     ↔ magic
#   0.846  magic                     ↔ quests
#   0.845  admin                     ↔ combat
#   0.845  persistence               ↔ clans
#   0.844  numerics                  ↔ skills_progression
#   0.844  runtime                   ↔ notes
#   0.844  memory                    ↔ entity_lookup
#   0.844  display                   ↔ clans
#   0.844  string_ops                ↔ objects
#   0.843  persistence               ↔ magic
#   0.843  entity_lookup             ↔ clans
#   0.842  string_ops                ↔ movement
#   0.841  combat                    ↔ social
#   0.841  output                    ↔ economy
#   0.841  social                    ↔ notes
#   0.841  movement                  ↔ notes
#   0.841  attributes                ↔ npc_behavior
#   0.840  arg_parsing               ↔ objects
#   0.840  memory                    ↔ economy
#   0.840  text_editing              ↔ affects
#   0.840  runtime                   ↔ visibility_rules
#   0.839  memory                    ↔ arg_parsing
#   0.839  text_editing              ↔ notes
#   0.839  arg_parsing               ↔ npc_behavior
#   0.839  memory                    ↔ movement
#   0.838  state_rules               ↔ world_structure
#   0.838  magic                     ↔ social
#   0.838  combat                    ↔ pvp
#   0.838  admin                     ↔ world_structure
#   0.837  affects                   ↔ world_structure
#   0.837  social                    ↔ quests
#   0.837  combat                    ↔ clans
#   0.836  economy                   ↔ quests
#   0.836  string_ops                ↔ affects
#   0.834  arg_parsing               ↔ skills_progression
#   0.834  flags                     ↔ entity_lookup
#   0.834  arg_parsing               ↔ state_rules
#   0.834  memory                    ↔ admin
#   0.834  text_editing              ↔ skills_progression
#   0.834  admin                     ↔ quests
#   0.834  visibility_rules          ↔ combat
#   0.833  economy                   ↔ npc_behavior
#   0.832  visibility_rules          ↔ skills_progression
#   0.832  numerics                  ↔ attributes
#   0.832  numerics                  ↔ world_structure
#   0.832  flags                     ↔ memory
#   0.830  arg_parsing               ↔ affects
#   0.830  runtime                   ↔ clans
#   0.830  text_editing              ↔ entity_lookup
#   0.830  skills_progression        ↔ clans
#   0.830  numerics                  ↔ output
#   0.829  state_rules               ↔ pvp
#   0.828  persistence               ↔ combat
#   0.828  visibility_rules          ↔ attributes
#   0.827  state_rules               ↔ notes
#   0.827  magic                     ↔ economy
#   0.827  text_editing              ↔ state_rules
#   0.827  combat                    ↔ economy
#   0.826  visibility_rules          ↔ output
#   0.826  visibility_rules          ↔ world_structure
#   0.825  numerics                  ↔ affects
#   0.825  numerics                  ↔ display
#   0.825  affects                   ↔ clans
#   0.825  visibility_rules          ↔ objects
#   0.824  arg_parsing               ↔ social
#   0.824  runtime                   ↔ pvp
#   0.823  arg_parsing               ↔ runtime
#   0.823  numerics                  ↔ runtime
#   0.823  skills_progression        ↔ pvp
#   0.823  memory                    ↔ skills_progression
#   0.822  numerics                  ↔ magic
#   0.822  clans                     ↔ npc_behavior
#   0.822  objects                   ↔ pvp
#   0.821  economy                   ↔ clans
#   0.821  memory                    ↔ attributes
#   0.821  social                    ↔ world_structure
#   0.820  string_ops                ↔ runtime
#   0.820  affects                   ↔ quests
#   0.820  visibility_rules          ↔ affects
#   0.820  attributes                ↔ clans
#   0.819  output                    ↔ clans
#   0.819  memory                    ↔ social
#   0.819  npc_behavior              ↔ world_structure
#   0.819  persistence               ↔ quests
#   0.819  numerics                  ↔ persistence
#   0.819  string_ops                ↔ social
#   0.819  numerics                  ↔ npc_behavior
#   0.818  string_ops                ↔ skills_progression
#   0.818  entity_lookup             ↔ notes
#   0.818  visibility_rules          ↔ quests
#   0.818  clans                     ↔ pvp
#   0.818  clans                     ↔ world_structure
#   0.818  affects                   ↔ notes
#   0.817  visibility_rules          ↔ social
#   0.816  memory                    ↔ clans
#   0.816  skills_progression        ↔ notes
#   0.816  text_editing              ↔ social
#   0.816  string_ops                ↔ npc_behavior
#   0.815  flags                     ↔ objects
#   0.815  numerics                  ↔ admin
#   0.815  memory                    ↔ state_rules
#   0.815  entity_lookup             ↔ pvp
#   0.814  admin                     ↔ clans
#   0.814  numerics                  ↔ movement
#   0.814  attributes                ↔ social
#   0.813  string_ops                ↔ numerics
#   0.813  numerics                  ↔ combat
#   0.813  arg_parsing               ↔ attributes
#   0.812  flags                     ↔ state_rules
#   0.812  numerics                  ↔ objects
#   0.811  numerics                  ↔ arg_parsing
#   0.811  visibility_rules          ↔ economy
#   0.811  pvp                       ↔ quests
#   0.811  string_ops                ↔ state_rules
#   0.810  text_editing              ↔ objects
#   0.810  memory                    ↔ npc_behavior
#   0.810  numerics                  ↔ entity_lookup
#   0.810  admin                     ↔ economy
#   0.810  clans                     ↔ quests
#   0.810  string_ops                ↔ imaging
#   0.809  imaging                   ↔ persistence
#   0.809  arg_parsing               ↔ economy
#   0.808  numerics                  ↔ memory
#   0.808  social                    ↔ economy
#   0.808  numerics                  ↔ economy
#   0.808  visibility_rules          ↔ magic
#   0.806  imaging                   ↔ output
#   0.806  display                   ↔ pvp
#   0.806  text_editing              ↔ npc_behavior
#   0.805  text_editing              ↔ combat
#   0.805  text_editing              ↔ magic
#   0.804  persistence               ↔ pvp
#   0.804  memory                    ↔ imaging
#   0.804  objects                   ↔ notes
#   0.804  string_ops                ↔ attributes
#   0.804  string_ops                ↔ economy
#   0.802  numerics                  ↔ state_rules
#   0.801  magic                     ↔ clans
#   0.801  quests                    ↔ world_structure
#   0.800  flags                     ↔ movement
#   0.799  magic                     ↔ pvp
#   0.798  attributes                ↔ pvp
#   0.797  imaging                   ↔ display
#   0.797  arg_parsing               ↔ magic
#   0.797  imaging                   ↔ entity_lookup
#   0.797  memory                    ↔ magic
#   0.796  combat                    ↔ notes
#   0.795  magic                     ↔ world_structure
#   0.795  flags                     ↔ affects
#   0.795  social                    ↔ pvp
#   0.795  visibility_rules          ↔ npc_behavior
#   0.794  text_editing              ↔ attributes
#   0.793  text_editing              ↔ quests
#   0.793  memory                    ↔ text_editing
#   0.792  npc_behavior              ↔ notes
#   0.792  affects                   ↔ pvp
#   0.791  flags                     ↔ social
#   0.791  magic                     ↔ notes
#   0.789  admin                     ↔ visibility_rules
#   0.789  attributes                ↔ notes
#   0.789  string_ops                ↔ notes
#   0.789  flags                     ↔ economy
#   0.788  imaging                   ↔ arg_parsing
#   0.788  output                    ↔ pvp
#   0.788  arg_parsing               ↔ notes
#   0.788  flags                     ↔ runtime
#   0.787  memory                    ↔ notes
#   0.786  string_ops                ↔ magic
#   0.786  flags                     ↔ npc_behavior
#   0.785  flags                     ↔ imaging
#   0.785  arg_parsing               ↔ clans
#   0.784  quests                    ↔ notes
#   0.783  pvp                       ↔ world_structure
#   0.783  memory                    ↔ pvp
#   0.783  economy                   ↔ notes
#   0.782  arg_parsing               ↔ combat
#   0.781  arg_parsing               ↔ quests
#   0.781  flags                     ↔ clans
#   0.780  text_editing              ↔ world_structure
#   0.778  pvp                       ↔ npc_behavior
#   0.778  combat                    ↔ world_structure
#   0.777  imaging                   ↔ objects
#   0.777  flags                     ↔ skills_progression
#   0.776  persistence               ↔ visibility_rules
#   0.775  numerics                  ↔ social
#   0.774  flags                     ↔ attributes
#   0.772  economy                   ↔ pvp
#   0.772  numerics                  ↔ clans
#   0.772  string_ops                ↔ clans
#   0.772  memory                    ↔ combat
#   0.771  clans                     ↔ notes
#   0.771  numerics                  ↔ flags
#   0.770  numerics                  ↔ quests
#   0.769  text_editing              ↔ economy
#   0.766  visibility_rules          ↔ clans
#   0.765  admin                     ↔ pvp
#   0.764  string_ops                ↔ combat
#   0.763  string_ops                ↔ quests
#   0.763  numerics                  ↔ imaging
#   0.763  memory                    ↔ quests
#   0.763  arg_parsing               ↔ visibility_rules
#   0.761  imaging                   ↔ movement
#   0.761  text_editing              ↔ clans
#   0.759  text_editing              ↔ visibility_rules
#   0.758  visibility_rules          ↔ notes
#   0.758  imaging                   ↔ admin
#   0.754  imaging                   ↔ economy
#   0.753  imaging                   ↔ attributes
#   0.752  imaging                   ↔ runtime
#   0.751  flags                     ↔ text_editing
#   0.751  flags                     ↔ visibility_rules
#   0.749  numerics                  ↔ text_editing
#   0.747  visibility_rules          ↔ pvp
#   0.747  notes                     ↔ world_structure
#   0.747  text_editing              ↔ pvp
#   0.745  flags                     ↔ notes
#   0.745  string_ops                ↔ visibility_rules
#   0.744  numerics                  ↔ pvp
#   0.742  imaging                   ↔ skills_progression
#   0.742  imaging                   ↔ affects
#   0.741  flags                     ↔ magic
#   0.741  arg_parsing               ↔ pvp
#   0.740  numerics                  ↔ visibility_rules
#   0.738  memory                    ↔ visibility_rules
#   0.736  imaging                   ↔ npc_behavior
#   0.735  string_ops                ↔ pvp
#   0.734  numerics                  ↔ notes
#   0.731  pvp                       ↔ notes
#   0.728  imaging                   ↔ visibility_rules
#   0.727  imaging                   ↔ state_rules
#   0.720  imaging                   ↔ social
#   0.720  flags                     ↔ combat
#   0.715  flags                     ↔ pvp
#   0.712  flags                     ↔ quests
#   0.706  imaging                   ↔ clans
#   0.703  imaging                   ↔ text_editing
#   0.693  imaging                   ↔ magic
#   0.683  imaging                   ↔ combat
#   0.683  imaging                   ↔ quests
#   0.664  imaging                   ↔ notes
#   0.656  imaging                   ↔ pvp

# %% [markdown]
# ## Step 7: Outlier detection & regroup suggestions
#
# Identify functions with low average similarity to their own group. Then check
# whether any neighbouring group would be a better semantic fit.
# Uses `EmbeddingRefiner.identify_outliers()` and `suggest_regroupings()`.

# %%
# ── Outlier detection ─────────────────────────────────────────────────
OUTLIER_THRESHOLD = 0.25  # fairly permissive — flags weakly-attached members
outliers = refiner.identify_outliers(subsystems, sim_matrices, threshold=OUTLIER_THRESHOLD)

print(f"Outliers (avg intra-group sim < {OUTLIER_THRESHOLD}): {len(outliers)}\n")

# Group outliers by their current group
outlier_by_group: dict[str, list] = defaultdict(list)
for o in outliers:
    outlier_by_group[o["current_subsystem"]].append(o)

for g in sorted(outlier_by_group, key=lambda g: -len(outlier_by_group[g])):
    members = outlier_by_group[g]
    print(f"[{g}] — {len(members)} outliers")
    for o in sorted(members, key=lambda x: x["average_similarity"]):
        info = callee_info.get(o["node_id"], {})
        brief = info.get("brief", "")
        b = f" — {brief[:55]}" if brief else ""
        print(f"  avg_sim={o['average_similarity']:.3f}  {o['name']:35s}{b}")

# ── Cross-group similarities & regroup suggestions ───────────────────
print(f"\n{'='*80}")
print("Computing cross-group similarities (this may take a moment)...")
cross_sims = refiner.calculate_cross_subsystem_similarities(group_embeddings)
suggestions = refiner.suggest_regroupings(outliers, cross_sims)

print(f"\nRegroup suggestions: {len(suggestions)}")
print(f"{'Name':35s} {'From':20s} {'To':20s} {'Δ sim':>7s}  {'Conf':>5s}")
print("-" * 95)
for s in suggestions[:40]:
    delta = s["suggested_similarity"] - s["current_similarity"]
    print(f"  {s['name']:33s} {s['current_subsystem']:20s} → {s['suggested_subsystem']:20s} "
          f"{delta:+.3f}  {s['confidence']:.2f}")
# Out:
# Outliers (avg intra-group sim < 0.25): 0
#
#
# ================================================================================
# Computing cross-group similarities (this may take a moment)...
#
# Regroup suggestions: 0
# Name                                From                 To                     Δ sim   Conf
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# ## Step 8: Per-group detail — members sorted by intra-group similarity
#
# For manual review: list each group's members sorted by their average similarity
# to fellow group members.  Functions near the bottom of each group are the most
# "edge-case" members worth eyeballing.

# %%
# ── Per-group member detail ───────────────────────────────────────────
# Set SHOW_GROUP to a group name (or None for all, or a type name for a category)
SHOW_GROUP = None  # e.g. "affects", "combat", "domain", None for all

def member_similarities(sim_data):
    """Return list of (node_id, avg_sim_to_peers)."""
    nids = sim_data["node_ids"]
    mat = sim_data["matrix"]
    n = len(nids)
    result = []
    for i, nid in enumerate(nids):
        if n > 1:
            peer_sims = [mat[i, j] for j in range(n) if i != j]
            result.append((nid, np.mean(peer_sims)))
        else:
            result.append((nid, 1.0))
    return sorted(result, key=lambda x: -x[1])

groups_to_show = []
if SHOW_GROUP is None:
    groups_to_show = list(CAPABILITY_DEFS.keys())
elif SHOW_GROUP in TYPE_ORDER:
    groups_to_show = [g for g in CAPABILITY_DEFS if GROUP_TYPE[g] == SHOW_GROUP]
elif SHOW_GROUP in CAPABILITY_DEFS:
    groups_to_show = [SHOW_GROUP]
else:
    print(f"Unknown group or type: {SHOW_GROUP}")

for g in groups_to_show:
    if g not in sim_matrices:
        continue
    sm = sim_matrices[g]
    ranked = member_similarities(sm)
    n = len(ranked)
    if n == 0:
        continue
    avg_all = np.mean([s for _, s in ranked])
    print(f"\n{'='*80}")
    print(f"[{GROUP_TYPE[g]}/{g}] — {n} members, avg cohesion {avg_all:.3f}")
    print(f"  {'avg_sim':>7s}  {'name':40s}  brief")
    print(f"  {'-'*7}  {'-'*40}  {'-'*40}")
    for nid, avg_s in ranked:
        info = callee_info.get(nid, {})
        name = info.get("name", nid[:12])
        brief = info.get("brief", "")
        b = brief[:55] if brief else ""
        marker = " ◄" if avg_s < 0.15 else ""
        print(f"  {avg_s:7.3f}  {name:40s}  {b}{marker}")
# Out:
# ================================================================================
# [domain/combat] — 25 members, avg cohesion 0.753
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.807  one_hit                                   Performs a single attack from one character to another,
#     0.798  mob_hit                                   Performs a comprehensive attack sequence for a characte
#     0.791  multi_hit                                 Performs a series of combat hits for a character agains
#     0.790  check_parry                               Checks whether the victim character successfully parrie
#     0.786  check_dodge                               Determines whether the victim character successfully do
#     0.779  check_dual_parry                          Checks if a character successfully parries an attack wi
#     0.773  damage                                    Handles the calculation, application, and messaging of
#     0.773  check_blur                                Evaluates whether a victim character successfully evade
#     0.772  kill_off                                  Handles the death of a victim character, including logg
#     0.768  check_shblock                             Checks if a character successfully blocks an incoming a
#     0.759  fireball_bash                             Performs a fireball bash attack that attempts to knock
#     0.755  xp_compute                                Calculates the experience points (XP) awarded to a char
#     0.754  trip                                      Attempts to trip a victim character, potentially causin
#     0.751  dragon                                    Executes a special dragon attack on a suitable victim d
#     0.751  set_fighting                              Initializes combat engagement between a character and a
#     0.741  raw_kill                                  Handles the complete death process for a character, inc
#     0.737  defense_heal                              Attempts a probabilistic defensive heal on a character,
#     0.735  death_cry                                 Handles a character's death event by broadcasting death
#     0.732  group_gain                                Calculates and distributes experience points (XP) among
#     0.726  prepare_char                              Prepares a character for a duel by relocating them to t
#     0.719  get_weapon_skill                          Determines the skill type associated with the weapon a
#     0.718  stop_fighting                             Stops fighting for a specified character and optionally
#     0.710  update_pos                                Updates the positional state of a character based on th
#     0.709  make_corpse                               Generates a corpse object from a character, transferrin
#     0.693  war_score_adjust                          Adjusts a clan's score during a war and handles defeat
#
# ================================================================================
# [domain/magic] — 6 members, avg cohesion 0.755
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.790  obj_cast_spell                            Performs a spell cast from an object on specified targe
#     0.776  chain_spell                               Executes a chain lightning spell that damages multiple
#     0.746  say_spell                                 Generates and broadcasts a stylized incantation message
#     0.745  dispel_char                               Attempts to dispel or cancel effects on a character bas
#     0.745  saves_spell                               Determines whether a character successfully resists a s
#     0.727  comp_spells                               Compares two spell information structures to determine
#
# ================================================================================
# [domain/affects] — 89 members, avg cohesion 0.744
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.785  affect::find_on_char                      Finds the first affect of a specified type applied to a
#     0.784  affect::iterate_over_char                 Iterates over all affects applied to a character and ap
#     0.780  affect::iterate_over_list                 Iterates over a doubly linked list of Affect objects, a
#     0.780  affect::remove_matching_from_char         Removes affects from a character's affect list that mat
#     0.778  affect::remove_type_from_char             Removes all affects of a specified type from a characte
#     0.778  affect::remove_matching_from_list         Removes Affect objects from a linked list that match a
#     0.778  affect::list_char                         Retrieves the linked list of active effects currently a
#     0.777  affect::sort_char                         Sorts the character's list of active affects according
#     0.775  affect::remort_affect_modify_char         Modifies a character's resistances or vulnerabilities b
#     0.774  affect::remove_matching_from_obj          Removes affects from an object’s affect list that match
#     0.774  check_dispel_char                         Checks and attempts to dispel a specific affect of a gi
#     0.773  affect_fn_dispel_char                     Evaluates a character's affect and marks it for dispell
#     0.773  affect::dedup_in_list                     Removes duplicate Affect objects from a list and merges
#     0.772  affect::find_on_obj                       Finds an affect of a specified type on a given object.
#     0.772  affect::list_obj                          Retrieves the list of effects currently applied to the
#     0.772  affect::find_in_list                      Locates the first Affect object of a specified type wit
#     0.771  affect::sort_obj                          Sorts the list of Affect objects associated with a give
#     0.770  affect::remove_marked_from_char           Removes all affects from a character that are marked fo
#     0.769  affect::exists_on_char                    Determines if a specific affect type is currently activ
#     0.767  affect::sort_list                         Sorts a linked list of Affect objects in place based on
#     0.766  affect::copy_to_char                      Copies an affect template to a character and applies it
#     0.765  affect::iterate_over_obj                  Iterates over an object's list of affects and applies a
#     0.765  affect::remove_all_from_obj               Removes all affects from an object that match the speci
#     0.764  affect::remove_all_from_char              Removes all affects from a character that match the spe
#     0.764  affect::remove_type_from_obj              Removes all affects of a specified type from the given
#     0.763  affect::remove_marked_from_obj            Removes all Affect objects marked for removal from the
#     0.763  affect::add_type_to_char                  Adds a specific affect type to a character, considering
#     0.762  affect::remove_from_list                  Removes a specified Affect object from a doubly linked
#     0.760  affect::modify_obj                        Delegates the modification of an object's affect list b
#     0.758  check_dispel_obj                          Checks for and dispels affects of a specified type from
#     0.758  affect::comparator_permanent              Determines whether two Affect objects share the same pe
#     0.758  affect::parse_flags                       Interprets a character flag to configure an Affect obje
#     0.758  rem_raff_affect                           Removes a specific remort affect from a character based
#     0.757  affect::comparator_type                   Compares two Affect objects based on their type attribu
#     0.757  affect_fn_dispel_obj                      Evaluates whether a specific affect on an object can be
#     0.757  affect::modify_char                       Casts the owner pointer to a Character and modifies its
#     0.756  affect::copy_to_list                      Creates a copy of an Affect object and inserts it into
#     0.756  affect::copy_flags_to_char                Applies a set of bit flags as effects or modifiers to a
#     0.756  affect::add_perm_to_char                  Adds a permanent affect of a specified type to a charac
#     0.754  affect::print_cache                       Generates a human-readable string listing all active af
#     0.751  undo_spell                                Attempts to undo or dispel affects of a specified type
#     0.751  affect::insert_in_list                    Inserts an Affect object at the beginning of a doubly l
#     0.750  affect::exists_on_obj                     Determines whether a specific affect of a given type ex
#     0.750  affect::swap                              Swaps the contents and list pointers of two Affect obje
#     0.750  affect::copy_to_obj                       Copies an affect template and adds it to the specified
#     0.750  affect::fn_fade_spell                     Decrements the duration of an affect and probabilistica
#     0.749  affect::join_to_char                      Integrates a new affect into a character's current list
#     0.748  affect::comparator_mark                   Compares two Affect objects based on their mark attribu
#     0.746  affect::in_cache                          Checks if a specific affect type is currently cached an
#     0.744  affect::join_to_obj                       Adds an Affect to an Object’s affect list, ensuring no
#     0.744  affect::checksum_list                     Calculates an order-insensitive checksum for a linked l
#     0.740  affect::clear_list                        Recursively deletes all nodes in a linked list of Affec
#     0.739  affect::list_room                         Retrieves the linked list of effects currently applied
#     0.739  affect::iterate_over_room                 Applies a specified callback function to each affect as
#     0.739  affect::remove_matching_from_room         Removes affects from a specified room that match a give
#     0.739  affect::lookup                            Retrieves the table entry associated with a specified a
#     0.738  affect::sort_room                         Sorts the list of Affect objects within a Room accordin
#     0.736  cold_effect                               Recursively applies a cold effect to a room, character,
#     0.735  raff_add_to_char                          Adds a remort affect to a character by modifying their
#     0.734  affect::modify_room                       Modifies the state of a room based on the addition or r
#     0.734  roll_mod                                  Generates and applies a random affect modification to a
#     0.731  roll_one_raff                             Randomly selects and assigns a remort affect to a victi
#     0.728  affect::attr_location_check               Checks if the provided location identifier is valid and
#     0.728  roll_raffects                             Assigns multiple random remort affects to a victim char
#     0.727  fire_effect                               Applies a recursive fire effect to a specified target,
#     0.727  get_affect_evolution                      Returns the highest evolution level of a specified affe
#     0.726  affect::add_racial_to_char                Applies racial effects, immunities, resistances, and vu
#     0.726  affect::bit_to_type                       Converts a bit flag from Flags::Bit to its correspondin
#     0.726  fix_blank_raff                            Removes zero-valued remort affects from a character's a
#     0.725  shock_effect                              Recursively applies a shock effect to game entities suc
#     0.725  affect::copy_to_room                      Copies an affect template into a specified room and upd
#     0.725  affect::comparator_duration               Compares two Affect objects based on their remaining du
#     0.724  affect::Affect::bitvector                 Returns a Flags object representing the current set of
#     0.722  gem::compile_effects                      Compiles and applies effects from gems attached to an o
#     0.721  room_update                               Updates all game rooms by managing effect durations, re
#     0.719  poison_effect                             Applies poison effects recursively to rooms, characters
#     0.718  affect_loc_name                           Returns the human-readable name corresponding to a spec
#     0.718  affect::checksum                          Calculates a checksum for an Affect object based on its
#     0.716  affect::enchanted_obj                     Determines whether an object has been enchanted by comp
#     0.715  acid_effect                               Applies acid effects recursively to rooms, characters,
#     0.714  spread_plague                             Attempts to spread a plague effect to characters in a r
#     0.713  check_cond                                Checks and applies damage to an object during combat, p
#     0.710  affect_index_lookup                       Finds the index of the first affect table entry whose n
#     0.710  enhance_blade                             Enhances a weapon object by applying a specified effect
#     0.698  check_protection_aura                     Checks for and applies aura-based effects such as shock
#     0.698  affect_callback_weaken_bonewall           Reduces the duration and strength of a bone wall affect
#     0.696  HAS_RAFF                                  Determines whether a player character has a specific re
#     0.639  raff_lookup                               Performs a linear search to find the index of a raffect
#     0.626  __attribute__::bitvector                  Returns a Flags object representing the current state o
#
# ================================================================================
# [domain/movement] — 34 members, avg cohesion 0.713
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.777  char_from_room                            Removes a character from its current room and updates t
#     0.766  char_to_room                              Moves a character into a specified room, defaulting to
#     0.766  move_char                                 Handles moving a character from their current room to a
#     0.764  Room::remove_char                         Removes a character from the room, updating occupant li
#     0.753  exits_in                                  Lists all rooms and portals that have exits leading int
#     0.752  find_exit                                 Determines the index of an exit door in the character's
#     0.744  scan_list                                 Iterates through all characters in a specified room and
#     0.740  find_door                                 Determines the index of a door in the character's curre
#     0.739  get_scatter_room                          Selects a random suitable room in the game world for sc
#     0.737  char_in_duel_room                         Checks if a character is currently located within a due
#     0.737  get_random_room                           Selects and returns a random suitable room for a charac
#     0.736  Room::add_char                            Adds a character to the room, updates the area's charac
#     0.733  Area::remove_char                         Removes a character from the area and updates the count
#     0.729  char_in_darena_room                       Checks if a character is currently located within any d
#     0.725  access_room                               Determines if a room accessible via a specific exit can
#     0.721  extract_char                              Removes a character from the game world, handling clean
#     0.712  World::remove_char                        Removes a specified character from the world's active c
#     0.710  stop_follower                             Terminates a character's following relationship, removi
#     0.710  get_position                              Determines the current position of a character, with sp
#     0.704  find_path                                 Performs a breadth-first search to find the shortest pa
#     0.697  obj_from_room                             Removes an Object from its current Room and updates all
#     0.696  checkexitstoroom                          Generates a descriptive string of one-way exits from a
#     0.693  obj_to_room                               Transfers an object into a specified room, handling spe
#     0.690  room_pair                                 Generates a formatted string representing the relations
#     0.690  Exit::keyword                             Retrieves the keyword associated with this Exit object
#     0.686  checkexits                                Analyzes the exits of a given room to identify and list
#     0.686  nuke_pets                                 Removes a character's pet from the game world, stopping
#     0.685  set_tail                                  Manages the creation, updating, and removal of tailing
#     0.684  recall                                    Handles the process of teleporting a character or their
#     0.678  IS_OUTSIDE                                Macro to determine if a character is located outdoors o
#     0.670  make_pet                                  Configures a character as a pet and establishes its rel
#     0.651  IS_FLYING                                 Macro to check if a character is in a flying state with
#     0.649  get_warp_loc_string                       Retrieves the warp location description from a warp cry
#     0.633  Exit::rev_dir                             Calculates the reverse direction index for a given dire
#
# ================================================================================
# [domain/skills_progression] — 33 members, avg cohesion 0.742
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.801  get_skill_level                           Calculates the effective skill level of a character for
#     0.776  check_improve                             Evaluates and potentially improves a character's skill
#     0.775  get_evolution                             Determines the evolution level of a character for a spe
#     0.775  get_learned                               Retrieves the learned skill level for a given character
#     0.773  get_weapon_learned                        Calculates the effective weapon skill level for a chara
#     0.770  get_random_skill                          Selects a random skill or spell that the character is e
#     0.764  find_spell                                Finds a spell that a character can cast based on a name
#     0.759  advance_level                             Calculates and applies attribute-based increases to a c
#     0.757  set_learned                               Sets the learned level of a specific skill for a player
#     0.756  group_add                                 Adds a specified skill or group to a character, updatin
#     0.756  prac_by_key                               Displays a sorted list of the character's known skills
#     0.756  completed_group                           Checks whether a character has fully completed a specif
#     0.755  evolve_list                               Displays a formatted list of skills and spells that the
#     0.753  exp_per_level                             Calculates the experience points needed for a character
#     0.752  gn_add                                    Marks a specified skill group as known to the character
#     0.750  get_skill_cost                            Calculates the mana or resource cost for a character to
#     0.749  npc_advance_level                         Increments an NPC's base hit points, mana, and stamina
#     0.748  demote_level                              Decreases a character's level by reducing their attribu
#     0.745  set_evolution                             Sets the evolution level for a specific skill type of a
#     0.743  skill::from_int                           Converts an integer identifier to its corresponding ski
#     0.743  prac_by_group                             Displays a categorized list of the character's known sk
#     0.742  can_evolve                                Checks whether a character can further evolve a specifi
#     0.739  get_usable_level                          Calculates the effective or usable level of a character
#     0.737  select_pose                               Selects an appropriate pose index for a character based
#     0.735  list_extraskill                           Displays a formatted list of extraclass remort skills a
#     0.729  skill::lookup                             Finds and returns the skill type whose name matches the
#     0.728  get_holdable_level                        Calculates the maximum level of items or actions a char
#     0.726  gain_exp                                  Increases a character's experience points and handles l
#     0.710  skill::num_skills                         Returns the total number of valid skills available in t
#     0.698  group_lookup                              Finds the index of a specified group within the global
#     0.672  guild_lookup                              Looks up and returns the guild enum corresponding to a
#     0.651  comp_groupnames                           Compares two group indices based on their associated gr
#     0.650  parse_deity                               Determines the index of a deity in the deity table base
#
# ================================================================================
# [domain/objects] — 44 members, avg cohesion 0.714
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.770  obj_to_char                               Associates an object with a character's inventory, upda
#     0.767  get_obj                                   Handles a character's attempt to pick up an object, per
#     0.764  obj_from_char                             Removes an object from a character's inventory and upda
#     0.764  obj_to_keeper                             Adds an object to a character's inventory, handling dup
#     0.756  obj_to_locker                             Adds an object to a player's locker storage, organizing
#     0.755  obj_from_locker                           Removes a specified object from a character's locker in
#     0.747  obj_from_strongbox                        Removes a specified object from a character's strongbox
#     0.744  obj_to_strongbox                          Adds an object to a character's strongbox storage, ensu
#     0.742  extract_obj                               Removes an object and all its contained items from the
#     0.738  equip_char                                Equips an object to a character at a specified wear loc
#     0.736  get_obj_number                            Calculates the total number of objects contained within
#     0.735  unequip_char                              Removes a specified object from a character's equipment
#     0.731  get_locker_number                         Calculates the total number of items stored in a charac
#     0.731  remove_obj                                Removes an equipped object from a character at a specif
#     0.726  spill_contents                            Distributes the contents of an object to their appropri
#     0.725  wear_obj                                  Attempts to equip a character with a specified object,
#     0.723  destroy_obj                               Destroys an in-game object by spilling its contents and
#     0.722  setup_obj                                 Configures or initializes an in-game object based on it
#     0.721  obj_from_obj                              Removes a specified object from its container’s content
#     0.720  recursive_clone                           Recursively clones an object and all its contained obje
#     0.719  create_object                             Creates and initializes a new in-game object instance b
#     0.718  get_obj_weight                            Calculates the total weight of an object, including all
#     0.716  generate_eq                               Generates a new in-game equipment object with randomize
#     0.712  obj_repair                                Repairs a specified object either through an NPC blacks
#     0.711  get_true_weight                           Calculates the total weight of an object including all
#     0.710  can_loot                                  Checks whether a character is authorized to loot a spec
#     0.710  vape_ceq_recursive                        Recursively vaporizes clan equipment objects within a s
#     0.705  item_type_name                            Returns the human-readable name corresponding to the ob
#     0.705  obj_to_obj                                Transfers an object into a specified container, with sp
#     0.704  get_owner                                 Retrieves the owner description of an object as perceiv
#     0.704  clone_object                              Copies all attributes, effects, and extended descriptio
#     0.695  count_users                               Counts the number of characters currently interacting w
#     0.688  get_legendary_name                        Generates a randomized legendary name for a specified e
#     0.688  add_base_stats                            Configures and assigns base statistical attributes and
#     0.687  has_modified_contents                     Checks whether the specified object contains any modifi
#     0.682  forge_flag                                Allows a character to forge a specific flag onto their
#     0.680  gem::inset                                Inserts a gem object into another object, establishing
#     0.676  is_anvil_owner                            Determines whether a character is the owner of a specif
#     0.671  ObjectValue::flags                        Returns a Flags object representing the current interna
#     0.668  ObjectValue::value                        Returns the integer value stored within the ObjectValue
#     0.667  vape_ceq                                  Removes all clan equipment objects from the specified c
#     0.663  get_base_name                             Retrieves the appropriate base name for a given equipme
#     0.662  anvil_owner_name                          Extracts and returns the owner's name from a private an
#     0.650  will_fit                                  Determines whether an object can be placed inside a spe
#
# ================================================================================
# [domain/social] — 10 members, avg cohesion 0.710
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.769  check_channel_social                      Checks if a social command matches a social interaction
#     0.750  check_social                              Checks if the input command matches a social interactio
#     0.728  remove_social                             Removes a social interaction entry from the social tabl
#     0.726  insert_social                             Inserts a Social object into the global social list whi
#     0.722  social_lookup                             Searches for and returns a pointer to a Social object w
#     0.698  channel                                   Handles toggling, formatting, and broadcasting messages
#     0.693  send_to_clan                              Sends a message to all online members of a specified cl
#     0.682  count_socials                             Counts and returns the total number of social interacti
#     0.672  ignore_offline                            Toggles ignoring or unignoring a specified offline play
#     0.655  config_censor                             Enables a character to view and modify their censorship
#
# ================================================================================
# [domain/economy] — 9 members, avg cohesion 0.678
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.705  get_cost                                  Calculates the appropriate transaction cost for an obje
#     0.703  create_money                              Creates an in-game object representing a specified amou
#     0.700  deduct_cost                               Handles the deduction or refund of in-game currency (go
#     0.696  find_money                                Updates the character's banked gold and silver by apply
#     0.677  silver_weight                             Macro that calculates the weight of silver coins from t
#     0.671  find_keeper                               Finds an accessible shopkeeper NPC in the character's c
#     0.667  Shop::is_questshop                        Checks whether the shop is designated as a quest shop b
#     0.664  gold_weight                               Calculates the weight of a specified amount of gold bas
#     0.623  Auction::is_participant                   Checks whether the given object is the current item bei
#
# ================================================================================
# [domain/clans] — 30 members, avg cohesion 0.740
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.783  clan_in_war                               Checks whether a specific clan is participating in a gi
#     0.781  war_start                                 Initializes and starts a new war between two clans, set
#     0.778  get_same_war                              Finds and returns the ongoing war in which both specifi
#     0.769  war_join                                  Adds a clan to a war as either a challenger or defender
#     0.768  war_stop                                  Ends an ongoing war, records final scores for participa
#     0.767  defeat_clan                               Handles the defeat of a clan within a war, updating war
#     0.767  clan_at_war                               Determines whether a specific clan is currently engaged
#     0.764  clan_opponents                            Determines whether two clans are opponents engaged in t
#     0.760  clan_is_challenger                        Determines whether a specified clan is actively partici
#     0.760  war_unjoin                                Removes or updates a clan's participation in a specific
#     0.758  count_clans                               Counts and returns the total number of clans currently
#     0.753  war_kill                                  Records a kill event between two characters involved in
#     0.747  war_lookup                                Retrieves the War object at the specified position in t
#     0.737  get_war_index                             Determines the 1-based position of a specific War insta
#     0.737  clan_lookup                               Searches for and returns the first Clan object whose na
#     0.730  war_win                                   Records a war victory event for the specified character
#     0.729  save_clan_table                           Saves the current state of all clans into the database,
#     0.725  calc_cp                                   Calculates the clan's power level based on its attribut
#     0.725  fix_war                                   Cleans up and reorganizes a War object by removing inva
#     0.724  war_power_adjust                          Adjusts the war-related power and clan points of a spec
#     0.719  is_clan                                   Checks whether a character is affiliated with a clan.
#     0.719  compare_clans                             Compares two Clan objects based on their names to deter
#     0.718  remove_clan                               Removes a clan from the global linked list based on its
#     0.718  count_clan_members                        Counts the number of members in a specified clan, optio
#     0.717  append_clan                               Adds a new Clan object to the end of the doubly linked
#     0.716  clan_vnum_lookup                          Finds and returns the Clan associated with a given virt
#     0.709  war_is_full                               Checks whether all participant slots on a specified sid
#     0.708  Room::clan                                Returns a pointer to the Clan associated with this room
#     0.706  rec_event                                 Creates a new war event with specified attributes and a
#     0.705  append_war                                Inserts a War object into the doubly linked list of war
#
# ================================================================================
# [domain/pvp] — 6 members, avg cohesion 0.802
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.844  remove_duel                               Removes a specified duel from the active duel list and
#     0.822  duel_kill                                 Handles the conclusion of a duel by removing the victim
#     0.809  get_duel                                  Retrieves the active duel involving the specified chara
#     0.797  append_duel                               Appends a Duel object to the end of the global duel lis
#     0.788  clear_arena                               Clears all non-immortal characters from the specified d
#     0.754  get_random_arena                          Selects and returns a randomly chosen arena from the cu
#
# ================================================================================
# [domain/quests] — 17 members, avg cohesion 0.794
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.829  squest_info                               Displays detailed information about the current skill q
#     0.828  generate_skillquest                       Initializes and assigns a skill quest to a character, i
#     0.825  quest_info                                Displays detailed information about a character's curre
#     0.825  generate_quest                            Generates a quest for a character by selecting a suitab
#     0.816  generate_skillquest_obj                   Generates a randomized skill quest object tailored for
#     0.813  generate_skillquest_mob                   Generates and places a quest-specific mobile character
#     0.811  squestobj_to_squestmob                    Handles the process of a character returning a quest ob
#     0.807  find_questmaster                          Finds and returns the questmaster NPC in the same room
#     0.805  find_squestmaster                         Locates the special quest master NPC in the current roo
#     0.796  quest_cleanup                             Resets all quest-related data and flags for the specifi
#     0.791  sq_cleanup                                Resets a character's quest-related data and cleans up a
#     0.779  quest_usage                               Displays the available QUEST commands to a character, i
#     0.776  generate_skillquest_room                  Selects an appropriate room for a skill quest based on
#     0.765  has_enough_qps                            Checks if a character has enough quest points or is an
#     0.754  IS_QUESTOR                                Macro to determine if a character is a player currently
#     0.753  IS_SQUESTOR                               Macro to determine if a character is a player who is cu
#     0.729  quest_level_diff                          Determines if the character's level and the monster's l
#
# ================================================================================
# [domain/npc_behavior] — 24 members, avg cohesion 0.768
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.816  mprog_act_trigger                         Adds a new action trigger to an NPC's action list if it
#     0.814  mprog_entry_trigger                       Checks if a mobile character should trigger its entry s
#     0.813  mprog_driver                              Processes and executes a list of scripted commands for
#     0.810  mprog_wordlist_check                      Checks a character's mobile programs for keyword or phr
#     0.808  mprog_speech_trigger                      Checks for and executes speech-related trigger scripts
#     0.806  mprog_give_trigger                        Handles 'give' trigger scripts for a mobile NPC when it
#     0.806  mprog_process_cmnd                        Processes a command string by expanding variable placeh
#     0.798  mprog_percent_check                       Performs a probabilistic check to trigger and execute m
#     0.792  mprog_death_trigger                       Triggers death-related scripts and effects for a charac
#     0.790  mprog_buy_trigger                         Checks if an NPC has a buy trigger program enabled and
#     0.789  mprog_translate                           Generates a context-sensitive string representation bas
#     0.789  mprog_process_if                          Evaluates 'if' conditions within MOBprogram command lis
#     0.788  mprog_tick_trigger                        Checks if the given mob has tick-based programs enabled
#     0.788  mprog_do_ifchck                           Evaluates conditional checks expressed as strings withi
#     0.780  mprog_bribe_trigger                       Handles the bribe event for an NPC, triggering scripted
#     0.759  mprog_greet_trigger                       Triggers greeting scripts for NPCs in the same room whe
#     0.725  mprog_veval                               Evaluates a comparison or bitwise operation between two
#     0.725  clone_mobile                              Duplicates the attributes, descriptive properties, and
#     0.723  create_mobile                             Creates and initializes a new mobile character instance
#     0.720  animate_mob                               Creates and summons a creature (mob) of specified type
#     0.717  mprog_next_command                        Advances the command list pointer to the start of the n
#     0.695  MobProg::type_to_name                     Converts a mobile program bit flag into its correspondi
#     0.693  hunt_victim                               Controls the pursuit and attack behavior of an NPC char
#     0.691  mprog_seval                               Performs a comparison between two strings based on a sp
#
# ================================================================================
# [policy/state_rules] — 56 members, avg cohesion 0.707
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.745  is_safe_char                              Determines whether it is unsafe for a character to atta
#     0.743  check_attack_ok                           Checks whether a character is permitted to initiate an
#     0.737  Character::has_cgroup                     Checks if a player character has any of the specified c
#     0.737  IS_THIEF                                  Macro to determine if a character has the thief status
#     0.737  clan_eq_ok                                Determines whether a character is authorized to perform
#     0.736  check_killer                              Checks whether a character should be flagged as a kille
#     0.736  IS_IMMORTAL                               Macro to determine if a character has at least immortal
#     0.735  IS_HERO                                   Macro to determine if a character qualifies as a hero b
#     0.734  Character::is_npc                         Determines whether the character is a non-player charac
#     0.730  IS_HEAD                                   Macro to determine if a character's rank is at or above
#     0.728  IS_REMORT                                 Macro that checks if a character is a remort player (no
#     0.728  IS_NEUTRAL                                Macro to determine if a character's alignment is neutra
#     0.727  OUTRANKS                                  Macro to determine if one character has a higher rank t
#     0.723  char_at_war                               Determines whether a character is actively involved in
#     0.722  is_ignoring                               Checks if a character is ignoring another character bas
#     0.722  is_same_clan                              Determines whether two characters belong to the same cl
#     0.721  char_in_duel                              Determines whether a character is currently engaged in
#     0.721  is_safe_spell                             Determines whether it is safe to cast a spell on a spec
#     0.720  is_safe                                   Determines whether it is safe for a character to attack
#     0.719  IS_IMP                                    Macro that checks if a character has the 'Implementor'
#     0.717  HAS_RAFF_GROUP                            Checks if a player character has any raffect belonging
#     0.715  pers_eq_ok                                Checks whether a character is authorized to use a speci
#     0.713  Character::add_cgroup                     Adds specified group flags to a player character's grou
#     0.712  IS_AWAKE                                  Macro to check if a character is awake based on their p
#     0.712  IS_EVIL                                   Macro to determine if a character's alignment classifie
#     0.709  IS_KILLER                                 Macro to determine if a character has been flagged as a
#     0.708  CAN_FLY                                   Macro to check if a character currently has the flying
#     0.708  char_opponents                            Determines whether two characters are opponents engaged
#     0.707  IS_SPECIAL                                Determines whether a character is considered 'special'
#     0.705  is_safe_drag                              Checks whether it is safe and permissible to drag or pu
#     0.705  CHARTYPE_TEST                             Macro that determines the entity type based on a charac
#     0.705  CAN_USE_RSKILL                            Determines whether a character has permission to use a
#     0.704  is_same_group                             Determines if two characters belong to the same group b
#     0.703  check_all_cond                            Checks and updates the condition of all equipment worn
#     0.701  IS_GOOD                                   Macro that checks if a character's alignment is conside
#     0.701  IS_HEROIC                                 Macro to determine if a character is either a hero or a
#     0.700  char_in_darena                            Checks if a character is actively engaged in an ongoing
#     0.698  check_pulse                               Checks and updates a character's health and positional
#     0.698  Descriptor::is_playing                    Checks if the descriptor is actively connected and curr
#     0.697  can_drop_obj                              Determines whether a character is permitted to drop a s
#     0.695  help_mob                                  Determines whether a character's attempt to help or hin
#     0.695  HAS_EXTRACLASS                            Checks if a character has a specific extra class skill
#     0.694  WAIT_STATE                                Macro to set a character's wait state, controlling acti
#     0.694  Character::remove_cgroup                  Removes specified group flags from a player character's
#     0.689  align                                     Attempts to change a character's alignment, with succes
#     0.689  add_follower                              Establishes a follower relationship by assigning a char
#     0.688  die_follower                              Removes all follower, pet, and special entity associati
#     0.683  from_box_ok                               Determines if a character can successfully take a speci
#     0.683  CHARTYPE_MATCH                            Macro to check if a character's entity type matches a s
#     0.683  DAZE_STATE                                Macro that sets or updates a character's dazed state ba
#     0.682  gain_condition                            Adjusts a character's specific condition (such as hunge
#     0.679  acceptable_sac                            Determines whether a given object is suitable for sacri
#     0.678  RANK                                      Macro to determine the rank type of an entity based on
#     0.663  CAN_WEAR                                  Checks if an object has a specific wear flag set, indic
#     0.657  IS_IMM_GROUP                              Macro that checks if a set of flags includes any of the
#     0.646  is_room_owner                             Checks whether a character is the owner of a specific r
#
# ================================================================================
# [policy/visibility_rules] — 10 members, avg cohesion 0.803
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.855  can_see_in_room                           Determines whether a character can see inside a specifi
#     0.819  can_see_obj                               Determines whether a character can see a specific objec
#     0.816  can_see_char                              Determines whether one character can see another charac
#     0.815  can_see_who                               Determines whether one character can see another charac
#     0.812  check_blind                               Checks whether a character can see, considering immorta
#     0.811  can_see_room                              Determines whether a character has permission to see or
#     0.797  is_blinded                                Determines whether a character is currently blinded by
#     0.789  Room::is_very_dark                        Determines whether the room is considered very dark bas
#     0.772  Room::is_dark                             Checks whether the room is currently dark based on ligh
#     0.747  Room::is_private                          Determines whether the room is considered private based
#
# ================================================================================
# [policy/attributes] — 45 members, avg cohesion 0.741
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.788  GET_ATTR_CHR                              Macro to retrieve a character's effective Charisma attr
#     0.786  GET_MAX_MANA                              Calculates the maximum mana a character can have based
#     0.782  GET_MAX_HIT                               Calculates the maximum hit points for a character, cons
#     0.779  GET_MAX_STAM                              Calculates and returns the maximum stamina value for a
#     0.779  GET_ATTR_HITROLL                          Macro to retrieve a character's total hit roll value, c
#     0.776  GET_ATTR_AC                               Computes the effective armor class (AC) for a character
#     0.774  get_max_stat                              Calculates the maximum attainable value for a specific
#     0.773  GET_ATTR                                  Macro to retrieve a character's effective attribute val
# ...
#   -------  ----------------------------------------  ----------------------------------------
#     0.827  util::Image::width                        Returns the width of the image in pixels.
#     0.822  util::Image::height                       Returns the height of the image in pixels.
#     0.802  util::Image::value                        Retrieves the value of a specified color or alpha chann
#     0.783  util::Image::load                         Loads a PNG image from the specified file and stores it
#
# ================================================================================
# [utility/text_editing] — 23 members, avg cohesion 0.797
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.837  edit_delete                               Deletes a specified range of lines from the current edi
#     0.825  edit_insert                               Inserts a given string into the current editing buffer
#     0.820  edit_goto1                                Sets the editing cursor to the specified line number wi
#     0.818  edit_desc                                 Initializes a text editing session for a character's lo
#     0.817  edit_list                                 Manages the display of a specified range of lines from
#     0.817  edit_list1                                Formats and displays a specified range of lines from th
#     0.816  check_line                                Checks whether a specified line number is within the va
#     0.815  edit_change                               Replaces a specified substring within a particular line
#     0.813  edit_help                                 Initiates editing of a help entry specified by its ID f
#     0.810  edit_note                                 Prepares a character's environment for editing an exist
#     0.805  edit_undo                                 Reverts the most recent change in the character's editi
#     0.804  edit_done                                 Finalizes and saves the current editing session for a c
#     0.800  list_window                               Displays a window of lines centered around the current
#     0.798  check_range                               Validates and sets a range of line numbers for editing
#     0.797  edit_split                                Splits the current line in the editing buffer at the fi
#     0.796  edit_goto                                 Moves the character's editing cursor to a specified lin
#     0.795  edit_status                               Displays the current editing status and available comma
#     0.790  edit_wrap                                 Reformats a selected portion of text in the editing buf
#     0.787  edit_cancel                               Cancels the current editing session for a character wit
#     0.763  find_line                                 Locates and returns a pointer to the start of the speci
#     0.760  backup                                    Creates a backup of the current edit string and enables
#     0.741  count_lines                               Counts the number of lines in the current editing buffe
#     0.698  is_blank_line                             Checks whether a given line consists solely of whitespa
#
# ================================================================================
# [domain/notes] — 10 members, avg cohesion 0.802
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.835  note_attach                               Attaches a new note to a character if they do not alrea
#     0.831  parse_note                                Handles various note commands such as reading, listing,
#     0.816  note_remove                               Removes a recipient from a note for a character or dele
#     0.811  notify_note_post                          Notifies relevant characters in the game world about a
#     0.810  update_read                               Updates the character's record of the most recent note
#     0.802  is_note_to                                Determines if a note is addressed to a specific charact
#     0.796  append_note                               Adds a new note to the appropriate in-memory list and a
#     0.794  hide_note                                 Determines whether a specific note should be hidden fro
#     0.764  count_spool                               Counts the number of notes in a spool that are visible
#     0.762  save_notes                                Saves all notes of a specified category to their design
#
# ================================================================================
# [utility/arg_parsing] — 14 members, avg cohesion 0.751
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.802  one_argument                              Extracts the first argument from a String and provides
#     0.784  _one_argument                             Extracts the first argument from the input string, hand
#     0.780  _mult_argument                            Parses an argument string to extract a leading numeric
#     0.780  _number_argument                          Extracts a leading numeric argument from a string, hand
#     0.773  mult_argument                             Parses an argument string to extract a leading numerica
#     0.771  number_argument                           Extracts a leading numeric prefix from a String argumen
#     0.758  one_keyword                               Extracts the next keyword from a string, correctly hand
#     0.751  _entity_argument                          Parses an argument string to identify specific entity t
#     0.745  entity_argument                           Parses an entity type from a string argument and update
#     0.738  String::has_words                         Determines whether all specified words or phrases in a
#     0.721  help_char_search                          Performs a database search for help entries with keywor
#     0.708  check_parse_name                          Checks whether a given name adheres to the game's namin
#     0.706  String::has_exact_words                   Determines whether all specified words in the given wor
#     0.704  swearcheck                                Checks whether the input string contains any predefined
#
# ================================================================================
# [infrastructure/runtime] — 9 members, avg cohesion 0.699
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.766  char_update                               Updates the state of all characters in the game world p
#     0.736  obj_update                                Updates all game objects by processing effects, timers,
#     0.729  World::update                             Updates the game world's areas at regular intervals and
#     0.710  GameTime::update                          Advances the in-game time by one hour, updating date, s
#     0.699  Weather::update                           Updates the weather conditions based on atmospheric pre
#     0.685  interpret                                 Interprets and executes a command or social interaction
#     0.672  World::add_char                           Adds a Character instance to the world's active charact
#     0.656  close_socket                              Closes a network connection associated with the specifi
#     0.635  check_disabled                            Checks if a given command is currently disabled in the
#
# ================================================================================
# [policy/entity_lookup] — 34 members, avg cohesion 0.762
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.808  get_obj_world                             Locates an object in the game world accessible to a cha
#     0.801  get_mob_here                              Locates a non-player character (NPC) in the same room a
#     0.801  get_char_here                             Locates a character in the same room as the specified c
#     0.799  get_char_world                            Locates a character in the game world based on specifie
#     0.797  fsearch_mobile                            Searches for NPC characters in the game world that matc
#     0.797  get_player_world                          Locates a player character in the game world based on a
#     0.796  fsearch_char                              Performs a search for characters and/or NPCs matching s
#     0.796  fsearch_obj                               Searches the game world for objects matching specific f
#     0.795  get_obj_here                              Locates an object accessible to the character in their
#     0.794  get_char_room                             Finds and returns a character in a specific room based
#     0.788  get_obj_list                              Finds and returns the nth object in a list that a chara
#     0.788  find_location                             Locates and returns the Room associated with a specifie
#     0.782  get_char_area                             Locates a character within the same area as the specifi
#     0.781  fsearch_player                            Searches for characters in the game world that match sp
#     0.780  get_mob_world                             Locates an NPC in the game world based on specified sea
#     0.780  get_obj_carry                             Retrieves an unworn, visible object from a character's
#     0.774  get_eq_char                               Retrieves the object equipped by a character at a speci
#     0.769  get_obj_keeper                            Retrieves a specific object from a keeper's inventory b
#     0.756  get_obj_wear                              Retrieves a worn object of a character based on specifi
#     0.755  fsearch_room                              Searches for rooms in the game world that are visible t
#     0.745  get_extra_descr                           Searches through a linked list of ExtraDescr objects to
#     0.745  weapon_lookup                             Finds the index of a weapon in the weapon table based o
#     0.741  get_weapon_type                           Determines the weapon type code based on the provided w
#     0.736  help                                      Retrieves and displays help text for a character based
#     0.731  quest_where                               Provides the last known location details of a quest-rel
#     0.731  name_expand                               Generates a unique, expanded name for a character withi
#     0.731  race_lookup                               Finds the index of a race in the race table based on it
#     0.726  get_warp_crystal                          Finds and returns the warp crystal object corresponding
#     0.724  liq_lookup                                Finds the index of a liquid in the table that matches t
#     0.716  has_key                                   Checks if a character is carrying an object with a spec
#     0.716  attack_lookup                             Finds the index of an attack in the attack table based
#     0.708  Area::get_obj_prototype                   Retrieves a pointer to the object prototype associated
#     0.704  random_prototype                          Selects a random object prototype VNUM whose name conta
#     0.702  World::get_obj_prototype                  Retrieves the object prototype associated with a given
#
# ================================================================================
# [domain/world_structure] — 36 members, avg cohesion 0.701
#   avg_sim  name                                      brief
#   -------  ----------------------------------------  ----------------------------------------
#     0.743  RoomID::get_vnum                          Retrieves the virtual number (vnum) associated with the
#     0.738  World::get_room                           Retrieves the Room object corresponding to a given Loca
#     0.738  Area::num_players                         Returns the number of player characters currently prese
#     0.735  Room::area                                Returns a reference to the Area object associated with
#     0.729  Room::name                                Returns a constant reference to the name of the room as
#     0.726  World::get_area                           Returns a pointer to the Area that contains the specifi
#     0.725  Vnum::value                               Returns the integer identifier stored within the Vnum o
#     0.724  RoomID::get_number                        Returns the human-readable room number if the RoomID is
#     0.719  QuestArea::area                           Returns a reference to the Area object associated with
#     0.719  Room::guild                               Returns the guild identifier associated with the room's
#     0.717  Room::flags                               Returns the combined set of flags that represent the cu
#     0.717  Location::to_int                          Returns a compact integer representation of the Locatio
#     0.712  Exit::key                                 Returns the key vnum associated with the Exit object.
#     0.711  worldmap::Worldmap::get_sector            Retrieves the sector type at a given coordinate within
#     0.711  Room::owner                               Retrieves the owner identifier associated with the room
#     0.708  RoomID::to_int                            Converts the RoomID into a compact integer representati
#     0.704  worldmap::Worldmap::height                Returns the vertical dimension (height) of the world ma
#     0.701  RoomID::num_bits_vnum                     Returns the fixed number of bits used to represent a vi
#     0.700  Room::sector_type                         Retrieves the sector type classification of the room ba
#     0.700  Room::mana_rate                           Retrieves the mana regeneration rate defined by the roo
#     0.695  Room::is_on_map                           Determines whether the room's location is within valid
#     0.695  >::get                                    Retrieves a pointer to the data associated with a speci
#     0.691  World::get_mob_prototype                  Retrieves the mobile prototype associated with a given
#     0.691  Area::get_mob_prototype                   Retrieves a pointer to the mobile prototype associated
#     0.690  GameTime::month_name                      Returns the name of the current month in the game's cus
#     0.690  worldmap::Coordinate::to_int              Converts the coordinate to a compact 32-bit integer rep
#     0.688  RoomID::is_valid                          Checks whether the RoomID has been properly initialized
#     0.687  Room::heal_rate                           Retrieves the healing rate defined by the room's protot
#     0.684  worldmap::Worldmap::width                 Returns the horizontal size of the world map in pixels.
#     0.680  Location::is_valid                        Checks whether the Location has a valid coordinate or r
#     0.679  Game::world                               Provides access to the singleton instance of the game w
#     0.679  worldmap::Coordinate::is_valid            Determines whether the coordinate is valid based on its
#     0.667  GameTime::day_name                        Returns the name of the current day in the game's weekl
#     0.666  >::get_child_index                        Calculates the index of the child quadrant within the q
#     0.641  sector_lookup                             Retrieves the human-readable name corresponding to a sp
#     0.628  Area::add_char                            Updates the count of player and immortal characters in

# %% [markdown]
# ## Step 9: t-SNE — global embedding landscape
#
# Project all callee embeddings into 2D via t-SNE, coloured by locked group.
# This gives a visual overview of cluster separation and overlap.

# %%
# ── Prepare data for t-SNE ────────────────────────────────────────────
# Collect all locked callees with embeddings
tsne_nids = []
tsne_groups = []
tsne_types = []
tsne_names = []

for g, embs in group_embeddings.items():
    for nid, vec in embs.items():
        tsne_nids.append(nid)
        tsne_groups.append(g)
        tsne_types.append(GROUP_TYPE[g])
        tsne_names.append(callee_info.get(nid, {}).get("name", "?"))

tsne_matrix = np.stack([callee_embeddings[nid] for nid in tsne_nids])
print(f"t-SNE input: {tsne_matrix.shape[0]} vectors, {tsne_matrix.shape[1]}d")

# ── Run t-SNE ────────────────────────────────────────────────────────
tsne = TSNE(n_components=2, perplexity=30, random_state=42, init="pca", learning_rate="auto")
tsne_2d = tsne.fit_transform(tsne_matrix)
print(f"t-SNE complete: {tsne_2d.shape}")

# ── Assign colours per group ─────────────────────────────────────────
unique_groups = sorted(set(tsne_groups))
cmap = plt.colormaps.get_cmap("tab20").resampled(len(unique_groups))
group_color_map = {g: cmap(i) for i, g in enumerate(unique_groups)}

# ── Global scatter plot ──────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(16, 12))
for g in unique_groups:
    idx = [i for i, gname in enumerate(tsne_groups) if gname == g]
    ax.scatter(tsne_2d[idx, 0], tsne_2d[idx, 1],
               c=[group_color_map[g]], label=g, s=12, alpha=0.7)

ax.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=7, ncol=2, markerscale=2)
ax.set_title("t-SNE: all locked callees coloured by capability group")
ax.set_xlabel("t-SNE 1")
ax.set_ylabel("t-SNE 2")
plt.tight_layout()
plt.show()
# Out:
# t-SNE input: 852 vectors, 768d
# t-SNE complete: (852, 2)

# %% [markdown]
# ## Step 10: t-SNE — per-group detail plots
#
# Highlight one group at a time against the greyed-out background of all other
# functions.  Useful for spotting members that land far from the group cluster.

# %%
# ── Per-group t-SNE detail plots ──────────────────────────────────────
# Show groups with at least MIN_MEMBERS members
MIN_MEMBERS = 5
groups_to_plot = [g for g in unique_groups if sum(1 for gn in tsne_groups if gn == g) >= MIN_MEMBERS]

n_plots = len(groups_to_plot)
ncols = 4
nrows = (n_plots + ncols - 1) // ncols
fig, axes = plt.subplots(nrows, ncols, figsize=(20, 5 * nrows))
axes = axes.flatten() if n_plots > 1 else [axes]

for idx, g in enumerate(groups_to_plot):
    ax = axes[idx]
    # Background: all other points in grey
    other_idx = [i for i, gn in enumerate(tsne_groups) if gn != g]
    ax.scatter(tsne_2d[other_idx, 0], tsne_2d[other_idx, 1],
               c="lightgrey", s=4, alpha=0.3)
    # Foreground: this group's points
    group_idx = [i for i, gn in enumerate(tsne_groups) if gn == g]
    ax.scatter(tsne_2d[group_idx, 0], tsne_2d[group_idx, 1],
               c=[group_color_map[g]], s=20, alpha=0.9, edgecolors="black", linewidths=0.3)

    # Label outlier members (those from step 7)
    outlier_nids_for_g = {o["node_id"] for o in outliers if o["current_subsystem"] == g}
    for i in group_idx:
        if tsne_nids[i] in outlier_nids_for_g:
            ax.annotate(tsne_names[i], (tsne_2d[i, 0], tsne_2d[i, 1]),
                       fontsize=5, alpha=0.8, color="red")

    ax.set_title(f"{g} ({len(group_idx)})", fontsize=9)
    ax.set_xticks([])
    ax.set_yticks([])

# Hide unused subplots
for idx in range(n_plots, len(axes)):
    axes[idx].set_visible(False)

fig.suptitle("Per-group t-SNE (outliers labelled in red)", fontsize=13, y=1.01)
plt.tight_layout()
plt.show()

# %%
# ── Summary statistics ────────────────────────────────────────────────
total_locked_matched = sum(len(nids) for nids in group_members.values())
total_with_emb = sum(len(e) for e in group_embeddings.values())

# Per-group avg cohesion
cohesions = {}
for g in CAPABILITY_DEFS:
    if g in sim_matrices:
        mat = sim_matrices[g]["matrix"]
        n = mat.shape[0]
        if n >= 2:
            mask = ~np.eye(n, dtype=bool)
            cohesions[g] = np.mean(mat[mask])

overall_cohesion = np.mean(list(cohesions.values())) if cohesions else 0

print("=" * 60)
print("SUMMARY")
print("=" * 60)
print(f"Groups: {len(CAPABILITY_DEFS)}")
print(f"Locked functions: {total_locked}")
print(f"Matched to callee pool: {total_locked_matched}")
print(f"With embeddings: {total_with_emb}")
print(f"Overall mean cohesion: {overall_cohesion:.3f}")
print(f"Outliers (< {OUTLIER_THRESHOLD}): {len(outliers)}")
print(f"Regroup suggestions: {len(suggestions)}")

print(f"\nGroups by cohesion:")
for g, c in sorted(cohesions.items(), key=lambda x: x[1]):
    n = len(group_embeddings.get(g, {}))
    print(f"  {c:.3f}  {g:25s} ({n:3d} members)  [{GROUP_TYPE[g]}]")
# Out:
# ============================================================
# SUMMARY
# ============================================================
# Groups: 30
# Locked functions: 852
# Matched to callee pool: 852
# With embeddings: 852
# Overall mean cohesion: 0.741
# Outliers (< 0.25): 0
# Regroup suggestions: 0
#
# Groups by cohesion:
#   0.678  output                    ( 57 members)  [projection]
#   0.678  economy                   (  9 members)  [domain]
#   0.684  persistence               ( 94 members)  [infrastructure]
#   0.699  runtime                   (  9 members)  [infrastructure]
#   0.701  world_structure           ( 36 members)  [domain]
#   0.702  display                   ( 27 members)  [projection]
#   0.707  state_rules               ( 56 members)  [policy]
#   0.709  memory                    ( 17 members)  [utility]
#   0.710  social                    ( 10 members)  [domain]
#   0.711  admin                     ( 10 members)  [infrastructure]
#   0.713  movement                  ( 34 members)  [domain]
#   0.714  objects                   ( 44 members)  [domain]
#   0.737  numerics                  ( 12 members)  [utility]
#   0.740  clans                     ( 30 members)  [domain]
#   0.741  attributes                ( 45 members)  [policy]
#   0.742  skills_progression        ( 33 members)  [domain]
#   0.744  affects                   ( 89 members)  [domain]
#   0.747  string_ops                ( 40 members)  [utility]
#   0.751  arg_parsing               ( 14 members)  [utility]
#   0.753  combat                    ( 25 members)  [domain]
#   0.755  magic                     (  6 members)  [domain]
#   0.762  entity_lookup             ( 34 members)  [policy]
#   0.768  npc_behavior              ( 24 members)  [domain]
#   0.789  flags                     ( 27 members)  [utility]
#   0.794  quests                    ( 17 members)  [domain]
#   0.797  text_editing              ( 23 members)  [utility]
#   0.802  notes                     ( 10 members)  [domain]
#   0.802  pvp                       (  6 members)  [domain]
#   0.803  visibility_rules          ( 10 members)  [policy]
#   0.809  imaging                   (  4 members)  [utility]

# %%
# ── Export locked classifications with cohesion metadata ──────────────
def _f(v):
    """Convert numpy scalars to Python float for JSON serialization."""
    return float(v) if hasattr(v, "item") else v

export = {
    "metadata": {
        "total_callees": len(all_callee_nodes),
        "locked": total_locked,
        "matched": total_locked_matched,
        "with_embedding": total_with_emb,
        "groups": len(CAPABILITY_DEFS),
        "overall_cohesion": round(float(overall_cohesion), 4),
        "outlier_threshold": OUTLIER_THRESHOLD,
        "n_outliers": len(outliers),
        "n_regroup_suggestions": len(suggestions),
    },
    "group_cohesion": {
        g: round(float(c), 4) for g, c in sorted(cohesions.items(), key=lambda x: x[1])
    },
    "outliers": [
        {
            "name": o["name"],
            "group": o["current_subsystem"],
            "avg_sim": round(float(o["average_similarity"]), 4),
        }
        for o in outliers
    ],
    "regroup_suggestions": [
        {
            "name": s["name"],
            "from": s["current_subsystem"],
            "to": s["suggested_subsystem"],
            "delta": round(float(s["suggested_similarity"] - s["current_similarity"]), 4),
            "confidence": round(float(s["confidence"]), 4),
        }
        for s in suggestions
    ],
}

out_path = HERE / "capability_classifications.json"
with open(out_path, "w") as f:
    json.dump(export, f, indent=2)
print(f"Exported to {out_path.name}")
# Out:
# Exported to capability_classifications.json
